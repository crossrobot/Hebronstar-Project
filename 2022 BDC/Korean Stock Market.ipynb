# %% [markdown]
# # Reference
#
# 1. open dart official document
# https://dart-fss.readthedocs.io/en/latest/welcome.html
#
# 2. 코딩 유치원
# https://coding-kindergarten.tistory.com/85

# %%
# install
# !pip install dart-fss
# Out:
# Requirement already satisfied: dart-fss in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (0.3.16)
# Requirement already satisfied: halo in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.0.31)
# Requirement already satisfied: xmltodict in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.12.0)
# Requirement already satisfied: py in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.11.0)
# Requirement already satisfied: traitlets in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (5.1.1)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (3.0.9)
# Requirement already satisfied: soupsieve in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2.3.1)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.26.7)
# Requirement already satisfied: pandas<1.3.0,>=1.1.5 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.2.5)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (4.62.3)
# Requirement already satisfied: attrs in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (21.4.0)
# Requirement already satisfied: idna>=3.0 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (3.3)
# Requirement already satisfied: appdirs in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.4.4)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (5.1.0)
# Requirement already satisfied: arelle in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2.2)
# Requirement already satisfied: python-dateutil in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2.8.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2.27.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.22.0)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: isodate in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.6.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2021.10.8)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.2.5)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.2.0)
# Requirement already satisfied: fake-useragent in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.1.11)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (0.7.5)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (4.8.0)
# Requirement already satisfied: chardet in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (4.0.0)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (2021.3)
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from dart-fss) (1.1)
# Requirement already satisfied: log-symbols>=0.0.14 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from halo->dart-fss) (0.0.14)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from halo->dart-fss) (0.4.4)
# Requirement already satisfied: spinners>=0.0.24 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from halo->dart-fss) (0.0.24)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from halo->dart-fss) (1.1.0)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from html5lib->dart-fss) (0.5.1)
# Requirement already satisfied: et-xmlfile in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from openpyxl->dart-fss) (1.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\envs\codingnj\lib\site-packages (from requests->dart-fss) (2.0.9)

# %%
# xml 파일을 읽기 위한 라이브러리
# from xml.etree.ElementTree import parse
# 판다스 
import pandas as pd
import os
import dart_fss as dart

# %% [markdown]
# My api key :7db60698e63bd621a006025500fe0436ee65cb47

# %% [markdown]
# dart 서비스에 올라가 있는 기업들은 비상장 기업들의 재무정보도 올라와 있다.
# 우리는 상장사의 재무정보만 보고 싶은 것이기 때문에, 전체 corp_list 중에서 상장기업들만 추출해야 한다.
#
# 상장사 리스트를 얻기 위해 한국거래소 > 기본 통계 > 주식 > 종목정보 > 전종목 기본정보에서 전종목 기본정보를 다운받는다.
# http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201040201

# %%
# 다운받은 전종목 기본정보 불러오기 
all_stocks = pd.read_excel('./data_5655_20220311.xlsx')
# Out:
# C:\Users\user\anaconda3\envs\codingNJ\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
all_stocks.head(1)
# Out:
#            표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0  KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
#
#                             영문 종목명         상장일    시장구분 증권구분    소속부 주식종류  액면가  \
# 0  Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권  벤처기업부  보통주  500
#
#      상장주식수
# 0  8312766

# %% [markdown]
# dart 패키지에서는 주식종목코드를 사용하는 것이아니라, dart 자체적인 corp_code(기업코드)를 가지고 정보를 불러온다.
# 따라서 한국거래소에서 얻은 상장기업 주식코드를 가지고, dart의 데이터에서 상장기업 리스트와, 그들의 corp_code를 추출한다.
# 여기서 주의 할 것은, 한국거래소에서 얻은 상장기업 주식코드에는 우선주도 포함된다는 점이다. 상장기업 주식코드중 보통주만 사용해야한다.

# %%
# 상장기업 주식 코드 중 보통주만 걸러내기 
listed_companies = all_stocks[all_stocks['주식종류']=='보통주']

# %%
import dart_fss as dart

# Open DART API KEY 설정
api_key='7db60698e63bd621a006025500fe0436ee65cb47'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.corp.get_corp_list()
# Out:
# Output()
# Output()
# Output()

# %%
# 상장 기업들의 기업코드와 회사 이름
listed_companies_corp_code = []
listed_companies_name = []

for stock_code in listed_companies['단축코드'] : 
    #corp_list.find_by_corp_name( ) 함수의 결과 데이터는 [[종목 코드]종목 이름]의 형태
    #이를 벗겨내기 위해서 corp_list.find_by_corp_name( )[0]으로 코딩함 
    try : 
        listed_companies_corp_code.append(corp_list.find_by_stock_code(stock_code).corp_code)
        listed_companies_name.append(corp_list.find_by_stock_code(stock_code).corp_name)
        
    except : 
        print(stock_code)
# Out:
# 225330

# %%
# 에러 확인. 현재 무슨일인지 모르겠지만 주식코드 225330, 씨엠에스에듀주식회사 정보를 얻어올 수 없다
corp_list.find_by_stock_code('225330')

# %% [markdown]
# (우선주를 제외한)상장기업들 수

# %%
len(listed_companies_name)
# Out:
# 2498

# %%
corp_code_df = pd.DataFrame({'기업이름':listed_companies_name, '기업코드' : listed_companies_corp_code})
corp_code_df.head(5)
# Out:
#       기업이름      기업코드
# 0  마이크로컨텍솔  00568188
# 1   스카이이앤엠  00814786
# 2    포스코엠텍  00128111
# 3   AJ네트웍스  00365387
# 4    AK홀딩스  00125080

# %%
# 삼성전자 code
corp_code = '00126380'

# 모든 상장된 기업 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자
samsung = corp_list.find_by_corp_code(corp_code=corp_code)

# 2019년 01월 01일 부터 연결재무제표 검색
# fs = samsung.extract_fs(bgn_de='20120101') 와 동일
fs = dart.fs.extract(corp_code=corp_code, bgn_de='20190101')
# Out:
# Annual reports:   0%|          | 0/4 [00:00<?, ?report/s]

# %% [markdown]
# ## 재무상태표(balance sheet(bs) or financial statement sheet) 가공

# %%
# class 를 제거, ifrs 공식 용어인 concept 제거, 이후 transpose, reset_index 
bs_df = fs.show('bs', show_class = False, show_concept = False).T.reset_index()
# level_1은 쓸모없는 설명 열 이므로 제거 
bs_df.drop(['level_1'],axis=1, inplace=True)
# 이렇게 전처리된 데이터 프레임에서 1번째 인덱스는 각 회계 항목의 영어이름(label_en)이다. 
# 영어이름이 혹시 필요하다면, 바로 아래 코드만 주석처리 해주면 된다. 지금은 일단 제거
bs_df.drop(1, inplace = True)

# %%
bs_df.columns = bs_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
bs_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
# 0번째 열이름이 이 재무제표의 title로 되어 있다. 이것을 account_year로 바꾼다. 
bs_df.rename(columns={bs_df.columns[0]:'Account_year'}, inplace = True) 
bs_df
# Out:
# 0 Account_year                  유동자산             현금및현금성자산  \
# 2     20211231 218,163,185,000,000.0 39,031,415,000,000.0
# 3     20201231 198,215,579,000,000.0 29,382,578,000,000.0
# 4     20191231 181,385,260,000,000.0 26,885,999,000,000.0
# 5     20181231 174,697,424,000,000.0 30,340,505,000,000.0
# 6     20171231 146,982,464,000,000.0 30,545,130,000,000.0
# 7     20161231 141,429,704,000,000.0 32,111,442,000,000.0
#
# 0               단기금융상품         단기상각후원가금융자산     단기당기손익-공정가치금융자산  \
# 2 81,708,986,000,000.0 3,369,034,000,000.0    40,757,000,000.0
# 3 92,441,703,000,000.0 2,757,111,000,000.0    71,451,000,000.0
# 4 76,252,052,000,000.0 3,914,216,000,000.0 1,727,436,000,000.0
# 5 65,893,797,000,000.0 2,703,693,000,000.0 2,001,948,000,000.0
# 6 49,447,696,000,000.0                 NaN                 NaN
# 7 52,432,411,000,000.0                 NaN                 NaN
#
# 0                 매출채권                 미수금                선급비용  \
# 2 40,713,415,000,000.0 4,497,257,000,000.0 2,336,252,000,000.0
# 3 30,965,058,000,000.0 3,604,539,000,000.0 2,266,100,000,000.0
# 4 35,131,343,000,000.0 4,179,120,000,000.0 2,406,220,000,000.0
# 5 33,867,733,000,000.0 3,080,733,000,000.0 4,136,167,000,000.0
# 6 27,695,995,000,000.0 4,108,961,000,000.0 3,835,219,000,000.0
# 7 24,279,211,000,000.0 3,521,197,000,000.0 3,502,083,000,000.0
#
# 0                 재고자산  ...               자본금            우선주자본금  \
# 2 41,384,404,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
# 3 32,043,145,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
# 4 26,766,464,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
# 5 28,984,704,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
# 6 24,983,355,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
# 7 18,353,503,000,000.0  ... 897,514,000,000.0 119,467,000,000.0
#
# 0            보통주자본금             주식발행초과금            이익잉여금(결손금)  \
# 2 778,047,000,000.0 4,403,893,000,000.0 293,064,763,000,000.0
# 3 778,047,000,000.0 4,403,893,000,000.0 271,068,211,000,000.0
# 4 778,047,000,000.0 4,403,893,000,000.0 254,582,894,000,000.0
# 5 778,047,000,000.0 4,403,893,000,000.0 242,698,956,000,000.0
# 6 778,047,000,000.0 4,403,893,000,000.0 215,811,200,000,000.0
# 7 778,047,000,000.0 4,403,893,000,000.0 193,086,317,000,000.0
#
# 0                기타자본항목      매각예정분류기타자본항목               비지배지분  \
# 2  -2,128,473,000,000.0               0.0 8,662,234,000,000.0
# 3  -8,687,155,000,000.0 -12,132,000,000.0 8,277,685,000,000.0
# 4  -4,968,829,000,000.0               0.0 7,964,949,000,000.0
# 5  -7,931,370,000,000.0               0.0 7,684,184,000,000.0
# 6 -13,899,191,000,000.0               NaN 7,278,012,000,000.0
# 7 -11,934,586,000,000.0 -28,810,000,000.0 6,538,705,000,000.0
#
# 0                  자본총계               부채와자본총계
# 2 304,899,931,000,000.0 426,621,158,000,000.0
# 3 275,948,016,000,000.0 378,235,718,000,000.0
# 4 262,880,421,000,000.0 352,564,497,000,000.0
# 5 247,753,177,000,000.0 339,357,244,000,000.0
# 6 214,491,428,000,000.0 301,752,090,000,000.0
# 7 192,963,033,000,000.0 262,174,324,000,000.0
#
# [6 rows x 54 columns]

# %% [markdown]
# ## 손익계산서 가공
# 'ci'는 포괄 손익 계산서,
# 'is'는 손익계산서.
# 둘 중 무엇으로?

# %%
is_df = fs.show('is', show_class = False, show_concept = True).T.reset_index()

# %%
# class 를 제거, ifrs 공식 용어인 concept 제거, 이후 transpose, reset_index 
is_df = fs.show('is', show_class = False, show_concept = False).T.reset_index()
# level_1은 쓸모없는 설명 열 이므로 제거 
is_df.drop(['level_1'],axis=1, inplace=True)
# 이렇게 전처리된 데이터 프레임에서 1번째 인덱스는 각 회계 항목의 영어이름(label_en)이다. 
# 영어이름이 혹시 필요하다면, 바로 아래 코드만 주석처리 해주면 된다. 지금은 일단 제거
is_df.drop(1, inplace = True)

# %%
is_df.columns = is_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
is_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
# 0번째 열이름이 이 재무제표의 title로 되어 있다. 이것을 account_year로 바꾼다. 
is_df.rename(columns={is_df.columns[0]:'Account_year'}, inplace = True) 
is_df
# Out:
# 0       Account_year               수익(매출액)                  매출원가  \
# 2  20210101-20211231 279,604,799,000,000.0 166,411,342,000,000.0
# 3  20200101-20201231 236,806,988,000,000.0 144,488,296,000,000.0
# 4  20190101-20191231 230,400,881,000,000.0 147,239,549,000,000.0
# 5  20180101-20181231 243,771,415,000,000.0 132,394,411,000,000.0
# 6  20170101-20171231 239,575,376,000,000.0 129,290,661,000,000.0
# 7  20160101-20161231 201,866,745,000,000.0 120,277,715,000,000.0
#
# 0                 매출총이익              판매비와관리비                 영업이익  \
# 2 113,193,457,000,000.0 61,559,601,000,000.0 51,633,856,000,000.0
# 3  92,318,692,000,000.0 56,324,816,000,000.0 35,993,876,000,000.0
# 4  83,161,332,000,000.0 55,392,823,000,000.0 27,768,509,000,000.0
# 5 111,377,004,000,000.0 52,490,335,000,000.0 58,886,669,000,000.0
# 6 110,284,715,000,000.0 56,639,677,000,000.0 53,645,038,000,000.0
# 7  81,589,030,000,000.0 52,348,358,000,000.0 29,240,672,000,000.0
#
# 0                기타수익                기타비용             지분법이익  \
# 2 2,205,695,000,000.0 2,055,971,000,000.0 729,614,000,000.0
# 3 1,384,068,000,000.0 2,488,902,000,000.0 506,530,000,000.0
# 4 1,778,666,000,000.0 1,414,707,000,000.0 412,960,000,000.0
# 5 1,485,037,000,000.0 1,142,018,000,000.0 539,845,000,000.0
# 6 3,010,657,000,000.0 1,419,648,000,000.0 201,442,000,000.0
# 7 3,238,261,000,000.0 2,463,814,000,000.0  19,501,000,000.0
#
# 0                 금융수익                 금융비용      법인세비용차감전순이익(손실)  \
# 2  8,543,187,000,000.0  7,704,554,000,000.0 53,351,827,000,000.0
# 3 12,267,600,000,000.0 11,318,055,000,000.0 36,345,117,000,000.0
# 4 10,161,632,000,000.0  8,274,871,000,000.0 30,432,189,000,000.0
# 5  9,999,321,000,000.0  8,608,896,000,000.0 61,159,958,000,000.0
# 6  9,737,391,000,000.0  8,978,913,000,000.0 56,195,967,000,000.0
# 7 11,385,645,000,000.0 10,706,613,000,000.0 30,713,652,000,000.0
#
# 0                법인세비용           계속영업이익(손실)            당기순이익(손실)  \
# 2 13,444,377,000,000.0 39,907,450,000,000.0 39,907,450,000,000.0
# 3  9,937,285,000,000.0 26,407,832,000,000.0 26,407,832,000,000.0
# 4  8,693,324,000,000.0 21,738,865,000,000.0 21,738,865,000,000.0
# 5 16,815,101,000,000.0 44,344,857,000,000.0 44,344,857,000,000.0
# 6 14,009,220,000,000.0 42,186,747,000,000.0 42,186,747,000,000.0
# 7  7,987,560,000,000.0 22,726,092,000,000.0 22,726,092,000,000.0
#
# 0 지배기업의 소유주에게 귀속되는 당기순이익(손실) 비지배지분에 귀속되는 당기순이익(손실) 기본주당이익(손실) 희석주당이익(손실)
# 2       39,243,791,000,000.0     663,659,000,000.0    5,777.0    5,777.0
# 3       26,090,846,000,000.0     316,986,000,000.0    3,841.0    3,841.0
# 4       21,505,054,000,000.0     233,811,000,000.0    3,166.0    3,166.0
# 5       43,890,877,000,000.0     453,980,000,000.0    6,461.0    6,461.0
# 6       41,344,569,000,000.0     842,178,000,000.0    5,997.0    5,997.0
# 7       22,415,655,000,000.0     310,437,000,000.0    3,159.0    3,159.0

# %% [markdown]
# ## 현금흐름표 가공

# %%
# class 를 제거, ifrs 공식 용어인 concept 제거, 이후 transpose, reset_index 
cf_df = fs.show('cf', show_class = False, show_concept = False).T.reset_index()
# level_1은 쓸모없는 설명 열 이므로 제거 
cf_df.drop(['level_1'],axis=1, inplace=True)
# 이렇게 전처리된 데이터 프레임에서 1번째 인덱스는 각 회계 항목의 영어이름(label_en)이다. 
# 영어이름이 혹시 필요하다면, 바로 아래 코드만 주석처리 해주면 된다. 지금은 일단 제거
cf_df.drop(1, inplace = True)

# %%
cf_df.columns = cf_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
cf_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
# 0번째 열이름이 이 재무제표의 title로 되어 있다. 이것을 account_year로 바꾼다. 
cf_df.rename(columns={cf_df.columns[0]:'Account_year'}, inplace = True) 
cf_df
# Out:
# 0       Account_year            영업활동 현금흐름        영업에서 창출된 현금흐름  \
# 2  20210101-20211231 65,105,448,000,000.0 72,676,199,000,000.0
# 3  20200101-20201231 65,287,009,000,000.0 68,148,810,000,000.0
# 4  20190101-20191231 45,382,915,000,000.0 56,635,791,000,000.0
# 5  20180101-20181231 67,031,863,000,000.0 78,025,064,000,000.0
# 6  20170101-20171231 62,162,041,000,000.0 67,777,432,000,000.0
# 7  20160101-20161231 47,385,644,000,000.0 52,299,610,000,000.0
#
# 0                당기순이익                   조정    영업활동으로 인한 자산부채의 변동  \
# 2 39,907,450,000,000.0 49,055,633,000,000.0 -16,286,884,000,000.0
# 3 26,407,832,000,000.0 41,618,554,000,000.0     122,424,000,000.0
# 4 21,738,865,000,000.0 37,442,682,000,000.0  -2,545,756,000,000.0
# 5 44,344,857,000,000.0 43,604,573,000,000.0  -9,924,366,000,000.0
# 6 42,186,747,000,000.0 36,211,232,000,000.0 -10,620,547,000,000.0
# 7 22,726,092,000,000.0 30,754,471,000,000.0  -1,180,953,000,000.0
#
# 0              이자의 수취            이자의 지급            배당금 수입  \
# 2 1,406,706,000,000.0 434,441,000,000.0 299,033,000,000.0
# 3 2,220,209,000,000.0 555,321,000,000.0 243,666,000,000.0
# 4 2,306,401,000,000.0 579,979,000,000.0 241,801,000,000.0
# 5 1,788,520,000,000.0 548,272,000,000.0 215,992,000,000.0
# 6 1,581,117,000,000.0 542,715,000,000.0 173,305,000,000.0
# 7 1,405,085,000,000.0 443,838,000,000.0 256,851,000,000.0
#
# 0              법인세 납부액  ...       단기차입금의 순증가(감소)           장기차입금의 차입  \
# 2  8,842,049,000,000.0  ... -2,616,943,000,000.0    58,279,000,000.0
# 3  4,770,355,000,000.0  ...  2,191,186,000,000.0    14,495,000,000.0
# 4 13,221,099,000,000.0  ...    865,792,000,000.0                 0.0
# 5 12,449,441,000,000.0  ... -2,046,470,000,000.0     3,580,000,000.0
# 6  6,827,098,000,000.0  ...  2,730,676,000,000.0   998,311,000,000.0
# 7  6,132,064,000,000.0  ...  1,351,037,000,000.0 1,041,743,000,000.0
#
# 0      사채 및 장기차입금의 상환              배당금의 지급         비지배지분의 증감         매각예정분류  \
# 2   894,749,000,000.0 20,510,350,000,000.0 -27,270,000,000.0  139,000,000.0
# 3   864,947,000,000.0  9,676,760,000,000.0   8,187,000,000.0 -139,000,000.0
# 4   709,400,000,000.0  9,639,202,000,000.0  -1,700,000,000.0            0.0
# 5 1,986,597,000,000.0 10,193,695,000,000.0   8,071,000,000.0            0.0
# 6 1,140,803,000,000.0  6,804,297,000,000.0   5,670,000,000.0            NaN
# 7   252,846,000,000.0  3,114,742,000,000.0  13,232,000,000.0            NaN
#
# 0     외화환산으로 인한 현금의 변동        현금및현금성자산의 순증감         기초의 현금및현금성자산  \
# 2  1,582,046,000,000.0  9,648,837,000,000.0 29,382,578,000,000.0
# 3   -833,861,000,000.0  2,496,579,000,000.0 26,885,999,000,000.0
# 4    595,260,000,000.0 -3,454,506,000,000.0 30,340,505,000,000.0
# 5     94,187,000,000.0   -204,625,000,000.0 30,545,130,000,000.0
# 6 -1,782,270,000,000.0 -1,566,312,000,000.0 32,111,442,000,000.0
# 7    417,243,000,000.0  9,474,698,000,000.0 22,636,744,000,000.0
#
# 0         기말의 현금및현금성자산
# 2 39,031,415,000,000.0
# 3 29,382,578,000,000.0
# 4 26,885,999,000,000.0
# 5 30,340,505,000,000.0
# 6 30,545,130,000,000.0
# 7 32,111,442,000,000.0
#
# [6 rows x 42 columns]

# %% [markdown]
# ## Integration
# 재무상태표, 현금흐름표, 손익계산서 하나의 dataframe으로 통합.

# %%
integrated_df = pd.concat([bs_df,is_df,cf_df], axis=1)

# %%
integrated_df['지배기업 소유주지분']
# Out:
# 2   296,237,697,000,000.0
# 3   267,670,331,000,000.0
# 4   254,915,472,000,000.0
# 5   240,068,993,000,000.0
# 6   207,213,416,000,000.0
# 7   186,424,328,000,000.0
# Name: 지배기업 소유주지분, dtype: object

# %%
len(integrated_df.columns)
# Out:
# 115

# %%
for i in integrated_df.columns : 
    print(i)
# Out:
# Account_year
# 유동자산
# 현금및현금성자산
# 단기금융상품
# 단기상각후원가금융자산
# 단기당기손익-공정가치금융자산
# 매출채권
# 미수금
# 선급비용
# 재고자산
# 기타유동자산
# 매각예정분류자산
# 비유동자산
# 기타포괄손익-공정가치금융자산
# 당기손익-공정가치금융자산
# 관계기업 및 공동기업 투자
# 유형자산
# 무형자산
# 순확정급여자산
# 이연법인세자산
# 기타비유동자산
# 자산총계
# 유동부채
# 매입채무
# 단기차입금
# 미지급금
# 선수금
# 예수금
# 미지급비용
# 당기법인세부채
# 유동성장기부채
# 충당부채
# 기타유동부채
# 매각예정분류부채
# 비유동부채
# 사채
# 장기차입금
# 장기미지급금
# 순확정급여부채
# 이연법인세부채
# 장기충당부채
# 기타비유동부채
# 부채총계
# 지배기업 소유주지분
# 자본금
# 우선주자본금
# 보통주자본금
# 주식발행초과금
# 이익잉여금(결손금)
# 기타자본항목
# 매각예정분류기타자본항목
# 비지배지분
# 자본총계
# 부채와자본총계
# Account_year
# 수익(매출액)
# 매출원가
# 매출총이익
# 판매비와관리비
# 영업이익
# 기타수익
# 기타비용
# 지분법이익
# 금융수익
# 금융비용
# 법인세비용차감전순이익(손실)
# 법인세비용
# 계속영업이익(손실)
# 당기순이익(손실)
# 지배기업의 소유주에게 귀속되는 당기순이익(손실)
# 비지배지분에 귀속되는 당기순이익(손실)
# 기본주당이익(손실)
# 희석주당이익(손실)
# Account_year
# 영업활동 현금흐름
# 영업에서 창출된 현금흐름
# 당기순이익
# 조정
# 영업활동으로 인한 자산부채의 변동
# 이자의 수취
# 이자의 지급
# 배당금 수입
# 법인세 납부액
# 투자활동 현금흐름
# 단기금융상품의 순감소(증가)
# 단기상각후원가금융자산의 순감소(증가)
# 단기당기손익-공정가치금융자산의 순감소(증가)
# 장기금융상품의 처분
# 장기금융상품의 취득
# 상각후원가금융자산의 처분
# 상각후원가금융자산의 취득
# 기타포괄손익-공정가치금융자산의 처분
# 기타포괄손익-공정가치금융자산의 취득
# 당기손익-공정가치금융자산의 처분
# 당기손익-공정가치금융자산의 취득
# 관계기업 및 공동기업 투자의 처분
# 관계기업 및 공동기업 투자의 취득
# 유형자산의 처분
# 유형자산의 취득
# 무형자산의 처분
# 무형자산의 취득
# 사업결합으로 인한 현금유출액
# 매각예정자산의 처분으로 인한 현금유입액
# 기타투자활동으로 인한 현금유출입액
# 재무활동 현금흐름
# 단기차입금의 순증가(감소)
# 장기차입금의 차입
# 사채 및 장기차입금의 상환
# 배당금의 지급
# 비지배지분의 증감
# 매각예정분류
# 외화환산으로 인한 현금의 변동
# 현금및현금성자산의 순증감
# 기초의 현금및현금성자산
# 기말의 현금및현금성자산

# %% [raw]
# 이 중 22년 3월 14일 현재 재무정보 중 추출해내야 할 것들은 :
# 1. 유동자산금액, 2. 비유동자산금액, 3.자산총계금액, 4.유동부채금액, 5.비유동부채금액, 6.부채총계금액, 7.소유주지분금액, 8.비지배지분금액 9.자본총계금액 10.부채자본총계금액 11.매출액 12.매출원가금액 13.매출총이익금액 14.판매비관리비금액 15.영업이익손실금액 16.금융수익금액 17. 금융비용금액 18.기타영업외수익금액 19.기타영업외비용금액 20.관계기업투자주식지분법손익금액 21.지분법이익금액 22.지분법손실금액 23.관계기업투자처분손익금액 24.관계기업투자손상차손금액 25. 관계기업투자손상차손환입금액 26.기타영업외손익금액 27.법인세비용금액 28.당기순이익금액 29.주당이익금액 30.영업활동현금흐름금액 31. 투자활동현금흐름금액 32.재무활동현금흐름금액 33.외화환산현금변동금액 34.현금자산순증감금액 35.기초현금자산금액 36.기말현금자산금액
#
# 총 36개의 데이터 필드

# %%
pd.DataFrame({'데이터정의서':['유동자산금액', '비유동자산금액', '자산총계금액', '유동부채금액', '비유동부채금액', '부채총계금액','소유주지분금액',
                      '비지배지분금액','자본총계금액','부채자본총계금액','매출액','매출원가금액','매출총이익금액','판매비와관리비금액',
                      '영업이익손실금액','금융수익금액','금융비용금액','기타영업외수익금액','기타영업외비용금액','관계기업투자주식지분법손익금액',
                      '지분법이익금액','지분법손실금액','관계기업투자처분손익금액',
                       '관계기업투자손상차손금액','관계기업투자손상차손환입금액','기타영업외손익금액', '법인세비용금액','당기순이익금액',
                       '주당이익금액','영업활동현금흐름금액','투자활동현금흐름금액','재무활동현금흐름금액','외화환산현금변동금액',
                       '현금자산순증감금액','기초현금자산금액','기말현금자산금액'],
             '재무상태표상용어' : ['유동자산', '비유동자산', '자산총계','유동부채','비유동부채','부채총계', '지배기업 소유주지분','비지배지분','자본총계','부채와자본총계'
                                              ,'수익(매출액)','매출원가','매출총이익','판매비와관리비','계속영업이익(손실)??','금융수입','금융비용',
                           '기타수익?','기타비용?', '-' ,'지분법이익','-' , '관계기업 및 공동기업 투자의 처분??','-' ,'-' , '??','법인세 납부액','당기순이익',
                           '희석주당이익,기본주당이익(중 무엇)?', '영업활동 현금흐름','투자활동 현금흐름','재무활동 현금흐름','외화환산으로 인한 현금의변동',
                           '현금및현금성자산의 순증감','기초의 현금및현금성자산','기말의 현금및현금성자산']})
# Out:
#              데이터정의서              재무상태표상용어
# 0            유동자산금액                  유동자산
# 1           비유동자산금액                 비유동자산
# 2            자산총계금액                  자산총계
# 3            유동부채금액                  유동부채
# 4           비유동부채금액                 비유동부채
# 5            부채총계금액                  부채총계
# 6           소유주지분금액            지배기업 소유주지분
# 7           비지배지분금액                 비지배지분
# 8            자본총계금액                  자본총계
# 9          부채자본총계금액               부채와자본총계
# 10              매출액               수익(매출액)
# 11           매출원가금액                  매출원가
# 12          매출총이익금액                 매출총이익
# 13        판매비와관리비금액               판매비와관리비
# 14         영업이익손실금액          계속영업이익(손실)??
# 15           금융수익금액                  금융수입
# 16           금융비용금액                  금융비용
# 17        기타영업외수익금액                 기타수익?
# 18        기타영업외비용금액                 기타비용?
# 19  관계기업투자주식지분법손익금액                     -
# 20          지분법이익금액                 지분법이익
# 21          지분법손실금액                     -
# 22     관계기업투자처분손익금액  관계기업 및 공동기업 투자의 처분??
# 23     관계기업투자손상차손금액                     -
# 24   관계기업투자손상차손환입금액                     -
# 25        기타영업외손익금액                    ??
# 26          법인세비용금액               법인세 납부액
# 27          당기순이익금액                 당기순이익
# 28           주당이익금액  희석주당이익,기본주당이익(중 무엇)?
# 29       영업활동현금흐름금액             영업활동 현금흐름
# 30       투자활동현금흐름금액             투자활동 현금흐름
# 31       재무활동현금흐름금액             재무활동 현금흐름
# 32       외화환산현금변동금액       외화환산으로 인한 현금의변동
# 33        현금자산순증감금액         현금및현금성자산의 순증감
# 34         기초현금자산금액          기초의 현금및현금성자산
# 35         기말현금자산금액          기말의 현금및현금성자산

# %% [markdown]
# ## 문제점발견 :
# 1. 데이터 정의서 상의 용어와 재무제표상 용어가 다르다... 혹시 재무상태표상 용어가 기업마다도 다를까?
# 2. 재무제표상 용어가 기업마다 약간씩 다를 수 있다.
#
# 현대의 경우를 살펴보자.

# %%
corp_code_df[corp_code_df['기업이름']=='현대자동차']
# Out:
#        기업이름      기업코드
# 2428  현대자동차  00164742

# %%
# 현대자동차 code
corp_code = '00164742'

# 모든 상장된 기업 리스트 불러오기
corp_list = dart.get_corp_list()

# 현대차
hyundai = corp_list.find_by_corp_code(corp_code=corp_code)

# 2019년 01월 01일 부터 연결재무제표 검색
# fs = samsung.extract_fs(bgn_de='20120101') 와 동일
fs = dart.fs.extract(corp_code=corp_code, bgn_de='20190101')
# Out:
# Annual reports:   0%|          | 0/5 [00:00<?, ?report/s]

# %%
hyundai
# Out:
# [00164742]현대자동차

# %%
hy_bs_df = fs.show('bs', show_class = True, show_concept = True).T.reset_index()
hy_bs_df
# Out:
#                                               level_0     level_1  \
# 0   [D210000] Statement of financial position, cur...  concept_id
# 1   [D210000] Statement of financial position, cur...    label_ko
# 2   [D210000] Statement of financial position, cur...    label_en
# 3   [D210000] Statement of financial position, cur...      class0
# 4   [D210000] Statement of financial position, cur...      class1
# 5   [D210000] Statement of financial position, cur...      class2
# 6   [D210000] Statement of financial position, cur...      class3
# 7                                            20211231   (연결재무제표,)
# 8                                            20201231   (연결재무제표,)
# 9                                            20191231   (연결재무제표,)
# 10                                           20181231   (연결재무제표,)
# 11                                           20171231   (연결재무제표,)
# 12                                           20161231   (연결재무제표,)
# 13                                           20141231   (연결재무제표,)
# 14                                           20131231   (연결재무제표,)
# 15                                           20121231   (연결재무제표,)
#
#                           0                                 1  \
# 0   ifrs-full_CurrentAssets  ifrs-full_CashAndCashEquivalents
# 1                      유동자산                          현금및현금성자산
# 2            Current assets         Cash and cash equivalents
# 3          재무상태표 [abstract]                  재무상태표 [abstract]
# 4             자산 [abstract]                     자산 [abstract]
# 5                      유동자산                              유동자산
# 6                      None                          현금및현금성자산
# 7      88,565,366,000,000.0              12,795,554,000,000.0
# 8      83,686,357,000,000.0               9,862,136,000,000.0
# 9      76,082,873,000,000.0               8,681,971,000,000.0
# 10     73,008,101,000,000.0               9,113,625,000,000.0
# 11     73,975,914,000,000.0               8,821,529,000,000.0
# 12     72,449,600,000,000.0               7,890,089,000,000.0
# 13     65,025,684,000,000.0               7,096,513,000,000.0
# 14     58,856,105,000,000.0               6,872,430,000,000.0
# 15     54,847,586,000,000.0               6,759,338,000,000.0
#
#                                                     2  \
# 0   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 1                                              단기금융상품
# 2                    Short-term financial instruments
# 3                                    재무상태표 [abstract]
# 4                                       자산 [abstract]
# 5                                                유동자산
# 6                                              단기금융상품
# 7                                 6,949,333,000,000.0
# 8                                 7,219,695,000,000.0
# 9                                 7,292,626,000,000.0
# 10                                7,936,319,000,000.0
# 11                                7,745,829,000,000.0
# 12                                7,361,735,000,000.0
# 13                                4,002,506,000,000.0
# 14                               14,875,288,000,000.0
# 15                               12,384,057,000,000.0
#
#                                         3  \
# 0   ifrs-full_OtherCurrentFinancialAssets
# 1                                  기타금융자산
# 2                  Other financial assets
# 3                        재무상태표 [abstract]
# 4                           자산 [abstract]
# 5                                    유동자산
# 6                                  기타금융자산
# 7                    12,396,646,000,000.0
# 8                    12,897,108,000,000.0
# 9                     9,449,913,000,000.0
# 10                    9,755,725,000,000.0
# 11                   12,886,769,000,000.0
# 12                   12,723,993,000,000.0
# 13                   14,884,434,000,000.0
# 14                      507,821,000,000.0
# 15                      109,299,000,000.0
#
#                                       4  \
# 0         dart_ShortTermTradeReceivable
# 1                                  매출채권
# 2   Trade notes and accounts receivable
# 3                      재무상태표 [abstract]
# 4                         자산 [abstract]
# 5                                  유동자산
# 6                                  매출채권
# 7                   3,147,296,000,000.0
# 8                   3,283,972,000,000.0
# 9                   3,513,090,000,000.0
# 10                  3,595,993,000,000.0
# 11                  3,838,043,000,000.0
# 12                  4,437,552,000,000.0
# 13                  3,750,092,000,000.0
# 14                  3,485,345,000,000.0
# 15                  3,686,824,000,000.0
#
#                                             5                      6  \
# 0   ifrs-full_TradeAndOtherCurrentReceivables  ifrs-full_Inventories
# 1                                        기타채권                   재고자산
# 2                           Other receivables            Inventories
# 3                            재무상태표 [abstract]       재무상태표 [abstract]
# 4                               자산 [abstract]          자산 [abstract]
# 5                                        유동자산                   유동자산
# 6                                        기타채권                   재고자산
# 7                         4,220,970,000,000.0   11,645,641,000,000.0
# 8                         4,016,972,000,000.0   11,333,734,000,000.0
# 9                         3,402,059,000,000.0   11,663,848,000,000.0
# 10                        3,291,847,000,000.0   10,714,858,000,000.0
# 11                        3,007,869,000,000.0   10,279,904,000,000.0
# 12                        3,181,030,000,000.0   10,523,812,000,000.0
# 13                        3,722,109,000,000.0    7,417,239,000,000.0
# 14                        3,118,386,000,000.0    7,073,116,000,000.0
# 15                        2,304,410,000,000.0    6,772,864,000,000.0
#
#                           7  ...                     48  \
# 0   dart_OtherCurrentAssets  ...  ifrs-full_Liabilities
# 1                      기타자산  ...                   부채총계
# 2              Other assets  ...      Total liabilities
# 3          재무상태표 [abstract]  ...       재무상태표 [abstract]
# 4             자산 [abstract]  ...          부채 [abstract]
# 5                      유동자산  ...                   부채총계
# 6                      기타자산  ...                   None
# 7       2,081,853,000,000.0  ...  151,330,626,000,000.0
# 8       2,033,371,000,000.0  ...  133,003,242,000,000.0
# 9       1,777,627,000,000.0  ...  118,146,466,000,000.0
# 10      1,770,682,000,000.0  ...  106,759,742,000,000.0
# 11      1,739,452,000,000.0  ...  103,442,100,000,000.0
# 12      1,389,803,000,000.0  ...  106,491,350,000,000.0
# 13      1,573,695,000,000.0  ...   84,604,552,000,000.0
# 14      1,667,936,000,000.0  ...   76,838,690,000,000.0
# 15      1,905,445,000,000.0  ...   73,620,239,000,000.0
#
#                                               49                       50  \
# 0   ifrs-full_EquityAttributableToOwnersOfParent  ifrs-full_IssuedCapital
# 1                                      지배기업소유주지분                      자본금
# 2        Equity attributable to owners of parent            Capital stock
# 3                               재무상태표 [abstract]         재무상태표 [abstract]
# 4                                  자본 [abstract]            자본 [abstract]
# 5                                      지배기업소유주지분                지배기업소유주지분
# 6                                           None                      자본금
# 7                           74,986,122,000,000.0      1,488,993,000,000.0
# 8                           69,480,633,000,000.0      1,488,993,000,000.0
# 9                           70,065,802,000,000.0      1,488,993,000,000.0
# 10                          67,973,969,000,000.0      1,488,993,000,000.0
# 11                          69,103,484,000,000.0      1,488,993,000,000.0
# 12                          67,189,658,000,000.0      1,488,993,000,000.0
# 13                          57,654,828,000,000.0      1,488,993,000,000.0
# 14                          51,931,085,000,000.0      1,488,993,000,000.0
# 15                          44,039,059,000,000.0      1,488,993,000,000.0
#
#                      51                                      52  \
# 0   dart_CapitalSurplus  dart_ElementsOfOtherStockholdersEquity
# 1                 자본잉여금                                  기타자본항목
# 2       Capital surplus                     Other capital items
# 3      재무상태표 [abstract]                        재무상태표 [abstract]
# 4         자본 [abstract]                           자본 [abstract]
# 5             지배기업소유주지분                               지배기업소유주지분
# 6                 자본잉여금                                  기타자본항목
# 7   4,070,260,000,000.0                    -1,968,385,000,000.0
# 8   4,190,093,000,000.0                    -1,700,592,000,000.0
# 9   4,197,015,000,000.0                    -1,516,817,000,000.0
# 10  4,201,214,000,000.0                    -1,155,244,000,000.0
# 11  4,201,214,000,000.0                    -1,640,096,000,000.0
# 12  4,202,597,000,000.0                    -1,640,096,000,000.0
# 13  4,134,550,000,000.0                    -1,273,752,000,000.0
# 14  4,130,668,000,000.0                    -1,128,779,000,000.0
# 15  4,158,988,000,000.0                    -1,128,779,000,000.0
#
#                                                    53  \
# 0   dart_OtherComprehensiveIncomeLossAccumulatedAm...
# 1                                           기타포괄손익누계액
# 2                Accumulated other comprehensive loss
# 3                                    재무상태표 [abstract]
# 4                                       자본 [abstract]
# 5                                           지배기업소유주지분
# 6                                           기타포괄손익누계액
# 7                                -1,772,601,000,000.0
# 8                                -3,409,661,000,000.0
# 9                                -2,353,022,000,000.0
# 10                               -3,052,198,000,000.0
# 11                               -2,278,955,000,000.0
# 12                               -1,223,244,000,000.0
# 13                               -1,344,826,000,000.0
# 14                                 -834,036,000,000.0
# 15                                 -473,373,000,000.0
#
#                             54                                 55  \
# 0   ifrs-full_RetainedEarnings  ifrs-full_NoncontrollingInterests
# 1                        이익잉여금                              비지배지분
# 2            Retained earnings          Non-controlling interests
# 3             재무상태표 [abstract]                   재무상태표 [abstract]
# 4                자본 [abstract]                      자본 [abstract]
# 5                    지배기업소유주지분                              비지배지분
# 6                        이익잉여금                               None
# 7         73,167,855,000,000.0                7,629,667,000,000.0
# 8         68,911,800,000,000.0                6,860,337,000,000.0
# 9         68,249,633,000,000.0                6,299,952,000,000.0
# 10        66,490,082,000,000.0                5,922,041,000,000.0
# 11        67,332,328,000,000.0                5,653,870,000,000.0
# 12        64,361,408,000,000.0                5,154,920,000,000.0
# 13        54,649,863,000,000.0                4,965,737,000,000.0
# 14        48,274,239,000,000.0                4,651,704,000,000.0
# 15        39,993,230,000,000.0                3,878,516,000,000.0
#
#                      56                              57
# 0      ifrs-full_Equity  ifrs-full_EquityAndLiabilities
# 1                  자본총계                         부채와자본총계
# 2          Total equity    Total equity and liabilities
# 3      재무상태표 [abstract]                재무상태표 [abstract]
# 4         자본 [abstract]                         부채와자본총계
# 5                  자본총계                            None
# 6                  None                            None
# 7  82,615,789,000,000.0           233,946,415,000,000.0
# 8  76,340,970,000,000.0           209,344,212,000,000.0
# 9  76,365,754,000,000.0           194,512,220,000,000.0
# 10 73,896,010,000,000.0           180,655,752,000,000.0
# 11 74,757,354,000,000.0           178,199,454,000,000.0
# 12 72,344,578,000,000.0           178,835,928,000,000.0
# 13 62,620,565,000,000.0           147,225,117,000,000.0
# 14 56,582,789,000,000.0           133,421,479,000,000.0
# 15 47,917,575,000,000.0           121,537,814,000,000.0
#
# [16 rows x 60 columns]

# %% [markdown]
# 현대차 재무상태표 가공

# %%
# class 를 제거, ifrs 공식 용어인 concept 제거, 이후 transpose, reset_index 
hy_bs_df = fs.show('bs', show_class = False, show_concept = False).T.reset_index()
# level_1은 쓸모없는 설명 열 이므로 제거 
hy_bs_df.drop(['level_1'],axis=1, inplace=True)
# 이렇게 전처리된 데이터 프레임에서 1번째 인덱스는 각 회계 항목의 영어이름(label_en)이다. 
# 영어이름이 혹시 필요하다면, 바로 아래 코드만 주석처리 해주면 된다. 지금은 일단 제거
hy_bs_df.drop(1, inplace = True)

# %%
hy_bs_df.columns = hy_bs_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
hy_bs_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
# 0번째 열이름이 이 재무제표의 title로 되어 있다. 이것을 account_year로 바꾼다. 
hy_bs_df.rename(columns={hy_bs_df.columns[0]:'Account_year'}, inplace = True) 
hy_bs_df
# Out:
# 0  Account_year                 유동자산             현금및현금성자산  \
# 2      20211231 88,565,366,000,000.0 12,795,554,000,000.0
# 3      20201231 83,686,357,000,000.0  9,862,136,000,000.0
# 4      20191231 76,082,873,000,000.0  8,681,971,000,000.0
# 5      20181231 73,008,101,000,000.0  9,113,625,000,000.0
# 6      20171231 73,975,914,000,000.0  8,821,529,000,000.0
# 7      20161231 72,449,600,000,000.0  7,890,089,000,000.0
# 8      20141231 65,025,684,000,000.0  7,096,513,000,000.0
# 9      20131231 58,856,105,000,000.0  6,872,430,000,000.0
# 10     20121231 54,847,586,000,000.0  6,759,338,000,000.0
#
# 0                단기금융상품               기타금융자산                매출채권  \
# 2   6,949,333,000,000.0 12,396,646,000,000.0 3,147,296,000,000.0
# 3   7,219,695,000,000.0 12,897,108,000,000.0 3,283,972,000,000.0
# 4   7,292,626,000,000.0  9,449,913,000,000.0 3,513,090,000,000.0
# 5   7,936,319,000,000.0  9,755,725,000,000.0 3,595,993,000,000.0
# 6   7,745,829,000,000.0 12,886,769,000,000.0 3,838,043,000,000.0
# 7   7,361,735,000,000.0 12,723,993,000,000.0 4,437,552,000,000.0
# 8   4,002,506,000,000.0 14,884,434,000,000.0 3,750,092,000,000.0
# 9  14,875,288,000,000.0    507,821,000,000.0 3,485,345,000,000.0
# 10 12,384,057,000,000.0    109,299,000,000.0 3,686,824,000,000.0
#
# 0                 기타채권                 재고자산                기타자산  \
# 2  4,220,970,000,000.0 11,645,641,000,000.0 2,081,853,000,000.0
# 3  4,016,972,000,000.0 11,333,734,000,000.0 2,033,371,000,000.0
# 4  3,402,059,000,000.0 11,663,848,000,000.0 1,777,627,000,000.0
# 5  3,291,847,000,000.0 10,714,858,000,000.0 1,770,682,000,000.0
# 6  3,007,869,000,000.0 10,279,904,000,000.0 1,739,452,000,000.0
# 7  3,181,030,000,000.0 10,523,812,000,000.0 1,389,803,000,000.0
# 8  3,722,109,000,000.0  7,417,239,000,000.0 1,573,695,000,000.0
# 9  3,118,386,000,000.0  7,073,116,000,000.0 1,667,936,000,000.0
# 10 2,304,410,000,000.0  6,772,864,000,000.0 1,905,445,000,000.0
#
# 0            당기법인세자산  ...                  부채총계            지배기업소유주지분  \
# 2   47,346,000,000.0  ... 151,330,626,000,000.0 74,986,122,000,000.0
# 3  138,848,000,000.0  ... 133,003,242,000,000.0 69,480,633,000,000.0
# 4  112,046,000,000.0  ... 118,146,466,000,000.0 70,065,802,000,000.0
# 5   97,271,000,000.0  ... 106,759,742,000,000.0 67,973,969,000,000.0
# 6   91,263,000,000.0  ... 103,442,100,000,000.0 69,103,484,000,000.0
# 7   46,924,000,000.0  ... 106,491,350,000,000.0 67,189,658,000,000.0
# 8   32,869,000,000.0  ...  84,604,552,000,000.0 57,654,828,000,000.0
# 9   54,845,000,000.0  ...  76,838,690,000,000.0 51,931,085,000,000.0
# 10  34,575,000,000.0  ...  73,620,239,000,000.0 44,039,059,000,000.0
#
# 0                  자본금               자본잉여금               기타자본항목  \
# 2  1,488,993,000,000.0 4,070,260,000,000.0 -1,968,385,000,000.0
# 3  1,488,993,000,000.0 4,190,093,000,000.0 -1,700,592,000,000.0
# 4  1,488,993,000,000.0 4,197,015,000,000.0 -1,516,817,000,000.0
# 5  1,488,993,000,000.0 4,201,214,000,000.0 -1,155,244,000,000.0
# 6  1,488,993,000,000.0 4,201,214,000,000.0 -1,640,096,000,000.0
# 7  1,488,993,000,000.0 4,202,597,000,000.0 -1,640,096,000,000.0
# 8  1,488,993,000,000.0 4,134,550,000,000.0 -1,273,752,000,000.0
# 9  1,488,993,000,000.0 4,130,668,000,000.0 -1,128,779,000,000.0
# 10 1,488,993,000,000.0 4,158,988,000,000.0 -1,128,779,000,000.0
#
# 0             기타포괄손익누계액                이익잉여금               비지배지분  \
# 2  -1,772,601,000,000.0 73,167,855,000,000.0 7,629,667,000,000.0
# 3  -3,409,661,000,000.0 68,911,800,000,000.0 6,860,337,000,000.0
# 4  -2,353,022,000,000.0 68,249,633,000,000.0 6,299,952,000,000.0
# 5  -3,052,198,000,000.0 66,490,082,000,000.0 5,922,041,000,000.0
# 6  -2,278,955,000,000.0 67,332,328,000,000.0 5,653,870,000,000.0
# 7  -1,223,244,000,000.0 64,361,408,000,000.0 5,154,920,000,000.0
# 8  -1,344,826,000,000.0 54,649,863,000,000.0 4,965,737,000,000.0
# 9    -834,036,000,000.0 48,274,239,000,000.0 4,651,704,000,000.0
# 10   -473,373,000,000.0 39,993,230,000,000.0 3,878,516,000,000.0
#
# 0                  자본총계               부채와자본총계
# 2  82,615,789,000,000.0 233,946,415,000,000.0
# 3  76,340,970,000,000.0 209,344,212,000,000.0
# 4  76,365,754,000,000.0 194,512,220,000,000.0
# 5  73,896,010,000,000.0 180,655,752,000,000.0
# 6  74,757,354,000,000.0 178,199,454,000,000.0
# 7  72,344,578,000,000.0 178,835,928,000,000.0
# 8  62,620,565,000,000.0 147,225,117,000,000.0
# 9  56,582,789,000,000.0 133,421,479,000,000.0
# 10 47,917,575,000,000.0 121,537,814,000,000.0
#
# [9 rows x 59 columns]

# %% [markdown]
# 현대차 손익계산서 가공

# %%
hy_is_df = fs.show('is', show_class = False, show_concept = False).T.reset_index()

# %%
# class 를 제거, ifrs 공식 용어인 concept 제거, 이후 transpose, reset_index 
hy_is_df = fs.show('is', show_class = False, show_concept = False).T.reset_index()
# level_1은 쓸모없는 설명 열 이므로 제거 
hy_is_df.drop(['level_1'],axis=1, inplace=True)
# 이렇게 전처리된 데이터 프레임에서 1번째 인덱스는 각 회계 항목의 영어이름(label_en)이다. 
# 영어이름이 혹시 필요하다면, 바로 아래 코드만 주석처리 해주면 된다. 지금은 일단 제거
hy_is_df.drop(1, inplace = True)

# %%
hy_is_df.columns = hy_is_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
hy_is_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
# 0번째 열이름이 이 재무제표의 title로 되어 있다. 이것을 account_year로 바꾼다. 
hy_is_df.rename(columns={hy_is_df.columns[0]:'Account_year'}, inplace = True) 
hy_is_df
# Out:
# 0        Account_year                   매출액                 매출원가  \
# 2   20210101-20211231 117,610,626,000,000.0 95,680,131,000,000.0
# 3   20200101-20201231 103,997,601,000,000.0 85,515,931,000,000.0
# 4   20190101-20191231 105,746,422,000,000.0 88,091,409,000,000.0
# 5   20180101-20181231  96,812,609,000,000.0 81,670,479,000,000.0
# 6   20170101-20171231  96,376,079,000,000.0 78,798,172,000,000.0
# 7   20160101-20161231  93,649,024,000,000.0 75,959,720,000,000.0
# 8   20140101-20141231  89,256,319,000,000.0 70,126,276,000,000.0
# 9   20130101-20131231  87,307,636,000,000.0 67,859,491,000,000.0
# 10  20120101-20121231  84,469,721,000,000.0 64,967,273,000,000.0
#
# 0                 매출총이익              판매비와관리비                영업이익  \
# 2  21,930,495,000,000.0 15,251,546,000,000.0 6,678,949,000,000.0
# 3  18,481,670,000,000.0 16,086,999,000,000.0 2,394,671,000,000.0
# 4  17,655,013,000,000.0 14,049,508,000,000.0 3,605,505,000,000.0
# 5  15,142,130,000,000.0 12,719,965,000,000.0 2,422,165,000,000.0
# 6  17,577,907,000,000.0 13,003,240,000,000.0 4,574,667,000,000.0
# 7  17,689,304,000,000.0 12,495,804,000,000.0 5,193,500,000,000.0
# 8  19,130,043,000,000.0 11,580,057,000,000.0 7,549,986,000,000.0
# 9  19,448,145,000,000.0 11,132,648,000,000.0 8,315,497,000,000.0
# 10 19,502,448,000,000.0 11,061,847,000,000.0 8,440,601,000,000.0
#
# 0        공동기업및관계기업투자손익                금융수익                금융비용  \
# 2  1,303,365,000,000.0   912,802,000,000.0   548,410,000,000.0
# 3    162,162,000,000.0   813,916,000,000.0   955,991,000,000.0
# 4    542,826,000,000.0   827,120,000,000.0   475,218,000,000.0
# 5    404,541,000,000.0   823,499,000,000.0   600,867,000,000.0
# 6    225,053,000,000.0   972,943,000,000.0 1,120,386,000,000.0
# 7  1,729,447,000,000.0 1,111,238,000,000.0   678,037,000,000.0
# 8  2,388,658,000,000.0   881,883,000,000.0   601,019,000,000.0
# 9  3,057,109,000,000.0   805,261,000,000.0   552,709,000,000.0
# 10 2,581,564,000,000.0   969,726,000,000.0   624,473,000,000.0
#
# 0                 기타수익  ...               법인세비용             연결당기순이익  \
# 2  1,447,261,000,000.0  ... 2,266,485,000,000.0 5,693,077,000,000.0
# 3  1,308,642,000,000.0  ...   168,703,000,000.0 1,924,553,000,000.0
# 4  1,120,958,000,000.0  ...   978,120,000,000.0 3,185,646,000,000.0
# 5    967,281,000,000.0  ...   884,563,000,000.0 1,645,019,000,000.0
# 6  1,153,744,000,000.0  ...  -107,850,000,000.0 4,546,400,000,000.0
# 7  1,177,887,000,000.0  ... 1,587,419,000,000.0 5,719,653,000,000.0
# 8  1,039,865,000,000.0  ... 2,301,806,000,000.0 7,649,468,000,000.0
# 9  1,138,001,000,000.0  ... 2,703,209,000,000.0 8,993,497,000,000.0
# 10 1,231,360,000,000.0  ... 2,549,310,000,000.0 9,061,132,000,000.0
#
# 0            지배기업소유주지분             비지배지분   기본주당이익 보통주 기본주당이익 1우선주 기본주당이익  \
# 2  4,942,356,000,000.0 750,721,000,000.0      NaN   18,979.0    19,002.0
# 3  1,424,436,000,000.0 500,117,000,000.0      NaN    5,454.0     5,502.0
# 4  2,980,049,000,000.0 205,597,000,000.0      NaN   11,310.0    11,355.0
# 5  1,508,084,000,000.0 136,935,000,000.0      NaN    5,632.0     5,681.0
# 6  4,032,824,000,000.0 513,576,000,000.0      NaN   14,993.0    15,043.0
# 7  5,406,435,000,000.0 313,218,000,000.0      NaN   20,118.0    20,156.0
# 8  7,346,807,000,000.0 302,661,000,000.0 27,037.0        NaN         NaN
# 9  8,541,834,000,000.0 451,663,000,000.0 31,441.0        NaN         NaN
# 10 8,566,568,000,000.0 494,564,000,000.0 31,532.0        NaN         NaN
#
# 0    희석주당이익 보통주 희석주당이익 1우선주 희석주당이익
# 2       NaN   18,979.0    19,002.0
# 3       NaN    5,454.0     5,502.0
# 4       NaN   11,310.0    11,355.0
# 5       NaN    5,632.0     5,681.0
# 6       NaN   14,993.0    15,043.0
# 7       NaN   20,118.0    20,156.0
# 8  27,037.0        NaN         NaN
# 9  31,441.0        NaN         NaN
# 10 31,532.0        NaN         NaN
#
# [9 rows x 22 columns]

# %% [markdown]
# 현대와 삼성의 손익계산서 필드명을 살펴 보자

# %%
is_df.columns
# Out:
# Index(['Account_year', '수익(매출액)', '매출원가', '매출총이익', '판매비와관리비', '영업이익', '기타수익',
#        '기타비용', '지분법이익', '금융수익', '금융비용', '법인세비용차감전순이익(손실)', '법인세비용',
#        '계속영업이익(손실)', '당기순이익(손실)', '지배기업의 소유주에게 귀속되는 당기순이익(손실)',
#        '비지배지분에 귀속되는 당기순이익(손실)', '기본주당이익(손실)', '희석주당이익(손실)'],
#       dtype='object', name=0)

# %%
hy_is_df.columns
# Out:
# Index(['Account_year', '매출액', '매출원가', '매출총이익', '판매비와관리비', '영업이익',
#        '  공동기업및관계기업투자손익', '  금융수익', '  금융비용', '  기타수익', '  기타비용',
#        '법인세비용차감전순이익', '법인세비용', '연결당기순이익', '지배기업소유주지분', '비지배지분', '기본주당이익',
#        '보통주 기본주당이익', '1우선주 기본주당이익', '희석주당이익', '보통주 희석주당이익', '1우선주 희석주당이익'],
#       dtype='object', name=0)

# %% [markdown]
# 필드명이 같은 것들이 대부분이지만, 다른 경우도 존재한다. 예를 들어서, 현대는 '매출액','기본주당이익'과 삼성은 '수익(매출액)','기본주당이익(손실)'로 표기한다. 이런 표기의 다름을 해결하기 위해, 표준화된 컬럼 이름을 사용하자.

# %%
# 삼성전자 code
corp_code = '00126380'

# 2019년 01월 01일 부터 연결재무제표 검색
# fs = samsung.extract_fs(bgn_de='20120101') 와 동일
fs = dart.fs.extract(corp_code=corp_code, bgn_de='20190101')

is_df = fs.show('is', show_class = False, show_concept = True)
# Out:
# Annual reports:   0%|          | 0/4 [00:00<?, ?report/s]

# %%
is_df = is_df.T.reset_index() 
is_df.columns = is_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
is_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
is_df.columns
# Out:
# Index(['[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)',
#        'concept_id', 'ifrs-full_Revenue', 'ifrs-full_CostOfSales',
#        'ifrs-full_GrossProfit',
#        'dart_TotalSellingGeneralAdministrativeExpenses',
#        'dart_OperatingIncomeLoss', 'dart_OtherGains', 'dart_OtherLosses',
#        'entity00126380_udf_IS_2017102191515184_IncomeStatementAbstract',
#        'ifrs-full_FinanceIncome',
#        'entity00126380_udf_IS_2017102191643789_IncomeStatementAbstract',
#        'ifrs-full_ProfitLossBeforeTax',
#        'ifrs-full_IncomeTaxExpenseContinuingOperations',
#        'ifrs-full_ProfitLossFromContinuingOperations', 'ifrs-full_ProfitLoss',
#        'ifrs-full_ProfitLossAttributableToOwnersOfParent',
#        'ifrs-full_ProfitLossAttributableToNoncontrollingInterests',
#        'ifrs-full_BasicEarningsLossPerShare',
#        'ifrs-full_DilutedEarningsLossPerShare'],
#       dtype='object', name=0)

# %%
is_df[['entity00126380_udf_IS_2017102191515184_IncomeStatementAbstract','entity00126380_udf_IS_2017102191643789_IncomeStatementAbstract']]
# Out:
# 0 entity00126380_udf_IS_2017102191515184_IncomeStatementAbstract  \
# 1                                              지분법이익
# 2  Share of net profit of associates and joint ve...
# 3                                  729,614,000,000.0
# 4                                  506,530,000,000.0
# 5                                  412,960,000,000.0
# 6                                  539,845,000,000.0
# 7                                  201,442,000,000.0
# 8                                   19,501,000,000.0
#
# 0 entity00126380_udf_IS_2017102191643789_IncomeStatementAbstract
# 1                                               금융비용
# 2                                  Financial expense
# 3                                7,704,554,000,000.0
# 4                               11,318,055,000,000.0
# 5                                8,274,871,000,000.0
# 6                                8,608,896,000,000.0
# 7                                8,978,913,000,000.0
# 8                               10,706,613,000,000.0

# %%
# 현대자동차 code
corp_code = '00164742'

# 모든 상장된 기업 리스트 불러오기
corp_list = dart.get_corp_list()

# 현대차
hyundai = corp_list.find_by_corp_code(corp_code=corp_code)

# 2019년 01월 01일 부터 연결재무제표 검색
# fs = samsung.extract_fs(bgn_de='20120101') 와 동일
fs = dart.fs.extract(corp_code=corp_code, bgn_de='20190101')
hy_is_df = fs.show('is', show_class = False, show_concept = True)
# Out:
# Annual reports:   0%|          | 0/5 [00:00<?, ?report/s]

# %%
hy_is_df = hy_is_df.T.reset_index() 
hy_is_df.columns = hy_is_df.iloc[0]  # 0번째 행을 열이름으로 바꾼다. 이렇게 함으로써 열 이름이 회계 세부 항목 이름으로 바뀌게 된다. 
hy_is_df.drop(0,inplace=True)  # 열이름으로 바꾼후, 0번째 행은 제거.

# %%
hy_cols = list(hy_is_df.columns)
sam_cols = list(is_df.columns)

# %%
# 공통부분 찾기 

print('공통부분')
print(set(hy_cols)&set(sam_cols))
print('다른부분1')
print(set(hy_cols)-set(sam_cols))
print('다른부분2')
print(set(sam_cols)-set(hy_cols))
# Out:
# 공통부분
# {'ifrs-full_ProfitLossBeforeTax', 'ifrs-full_Revenue', 'dart_TotalSellingGeneralAdministrativeExpenses', 'dart_OperatingIncomeLoss', 'ifrs-full_GrossProfit', 'ifrs-full_IncomeTaxExpenseContinuingOperations', 'ifrs-full_CostOfSales', 'concept_id', 'ifrs-full_DilutedEarningsLossPerShare', 'ifrs-full_ProfitLossAttributableToOwnersOfParent', 'ifrs-full_FinanceIncome', 'dart_OtherLosses', 'ifrs-full_BasicEarningsLossPerShare', 'ifrs-full_ProfitLossAttributableToNoncontrollingInterests', '[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', 'dart_OtherGains'}
# 다른부분1
# {'entity00164742_udf_IS_20171121623772_DilutedEarningsLossPerShare', 'entity00164742_udf_IS_201811515595499_IncomeStatementAbstract', 'entity00164742_udf_IS_201711292448594_IncomeStatementAbstract', 'ifrs-full_FinanceCosts', 'entity00164742_udf_IS_201711216052534_BasicEarningsLossPerShare', 'entity00164742_udf_IS_20171121628395_DilutedEarningsLossPerShare', 'entity00164742_udf_IS_201711216150750_BasicEarningsLossPerShare'}
# 다른부분2
# {'ifrs-full_ProfitLoss', 'entity00126380_udf_IS_2017102191515184_IncomeStatementAbstract', 'ifrs-full_ProfitLossFromContinuingOperations', 'entity00126380_udf_IS_2017102191643789_IncomeStatementAbstract'}

# %%
# 현대차 손익계산표에서 다른 부분 
hy_is_df[list(set(hy_cols)-set(sam_cols))]
# Out:
# 0  entity00164742_udf_IS_20171121623772_DilutedEarningsLossPerShare  \
# 1                                          보통주 희석주당이익
# 2            Diluted earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_201811515595499_IncomeStatementAbstract  \
# 1                                             연결당기순이익
# 2                                          Net income
# 3                                 5,693,077,000,000.0
# 4                                 1,924,553,000,000.0
# 5                                 3,185,646,000,000.0
# 6                                 1,645,019,000,000.0
# 7                                 4,546,400,000,000.0
# 8                                 5,719,653,000,000.0
# 9                                 7,649,468,000,000.0
# 10                                8,993,497,000,000.0
# 11                                9,061,132,000,000.0
#
# 0  entity00164742_udf_IS_201711292448594_IncomeStatementAbstract  \
# 1                                       공동기업및관계기업투자손익
# 2   Share of profit (loss) of associates and joint...
# 3                                 1,303,365,000,000.0
# 4                                   162,162,000,000.0
# 5                                   542,826,000,000.0
# 6                                   404,541,000,000.0
# 7                                   225,053,000,000.0
# 8                                 1,729,447,000,000.0
# 9                                 2,388,658,000,000.0
# 10                                3,057,109,000,000.0
# 11                                2,581,564,000,000.0
#
# 0  ifrs-full_FinanceCosts  \
# 1                    금융비용
# 2           Finance costs
# 3       548,410,000,000.0
# 4       955,991,000,000.0
# 5       475,218,000,000.0
# 6       600,867,000,000.0
# 7     1,120,386,000,000.0
# 8       678,037,000,000.0
# 9       601,019,000,000.0
# 10      552,709,000,000.0
# 11      624,473,000,000.0
#
# 0  entity00164742_udf_IS_201711216052534_BasicEarningsLossPerShare  \
# 1                                          보통주 기본주당이익
# 2              Basic earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_20171121628395_DilutedEarningsLossPerShare  \
# 1                                         1우선주 희석주당이익
# 2         Diluted earnings (loss) per preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_201711216150750_BasicEarningsLossPerShare
# 1                                         1우선주 기본주당이익
# 2       Basic earnings (loss) per 1st preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN

# %%
hy_is_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19140/911576590.py in <module>
# ----> 1 hy_is_df
#
# NameError: name 'hy_is_df' is not defined

# %%
# 삼성 손익계산표에서 다른 부분 
is_df[list(set(sam_cols)-set(hy_cols))]
# Out:
# 0          ifrs-full_ProfitLoss  \
# 1                     당기순이익(손실)
# 2  Profit (loss) for the period
# 3          39,907,450,000,000.0
# 4          26,407,832,000,000.0
# 5          21,738,865,000,000.0
# 6          44,344,857,000,000.0
# 7          42,186,747,000,000.0
# 8          22,726,092,000,000.0
#
# 0 entity00126380_udf_IS_2017102191515184_IncomeStatementAbstract  \
# 1                                              지분법이익
# 2  Share of net profit of associates and joint ve...
# 3                                  729,614,000,000.0
# 4                                  506,530,000,000.0
# 5                                  412,960,000,000.0
# 6                                  539,845,000,000.0
# 7                                  201,442,000,000.0
# 8                                   19,501,000,000.0
#
# 0 ifrs-full_ProfitLossFromContinuingOperations  \
# 1                                   계속영업이익(손실)
# 2     Profit (loss) from continuing operations
# 3                         39,907,450,000,000.0
# 4                         26,407,832,000,000.0
# 5                         21,738,865,000,000.0
# 6                         44,344,857,000,000.0
# 7                         42,186,747,000,000.0
# 8                         22,726,092,000,000.0
#
# 0 entity00126380_udf_IS_2017102191643789_IncomeStatementAbstract
# 1                                               금융비용
# 2                                  Financial expense
# 3                                7,704,554,000,000.0
# 4                               11,318,055,000,000.0
# 5                                8,274,871,000,000.0
# 6                                8,608,896,000,000.0
# 7                                8,978,913,000,000.0
# 8                               10,706,613,000,000.0

# %%
is_df['ifrs-full_ProfitLossAttributableToNoncontrollingInterests']
# Out:
# 1        비지배지분에 귀속되는 당기순이익(손실)
# 2    Non-controlling interests
# 3            663,659,000,000.0
# 4            316,986,000,000.0
# 5            233,811,000,000.0
# 6            453,980,000,000.0
# 7            842,178,000,000.0
# 8            310,437,000,000.0
# Name: ifrs-full_ProfitLossAttributableToNoncontrollingInterests, dtype: object

# %%
hy_is_df[['entity00164742_udf_IS_201711292448594_IncomeStatementAbstract','entity00164742_udf_IS_201811515595499_IncomeStatementAbstract','entity00164742_udf_IS_201711216052534_BasicEarningsLossPerShare','entity00164742_udf_IS_201711216150750_BasicEarningsLossPerShare','entity00164742_udf_IS_20171121623772_DilutedEarningsLossPerShare','entity00164742_udf_IS_20171121628395_DilutedEarningsLossPerShare']]
# Out:
# 0  entity00164742_udf_IS_201711292448594_IncomeStatementAbstract  \
# 1                                       공동기업및관계기업투자손익
# 2   Share of profit (loss) of associates and joint...
# 3                                 1,303,365,000,000.0
# 4                                   162,162,000,000.0
# 5                                   542,826,000,000.0
# 6                                   404,541,000,000.0
# 7                                   225,053,000,000.0
# 8                                 1,729,447,000,000.0
# 9                                 2,388,658,000,000.0
# 10                                3,057,109,000,000.0
# 11                                2,581,564,000,000.0
#
# 0  entity00164742_udf_IS_201811515595499_IncomeStatementAbstract  \
# 1                                             연결당기순이익
# 2                                          Net income
# 3                                 5,693,077,000,000.0
# 4                                 1,924,553,000,000.0
# 5                                 3,185,646,000,000.0
# 6                                 1,645,019,000,000.0
# 7                                 4,546,400,000,000.0
# 8                                 5,719,653,000,000.0
# 9                                 7,649,468,000,000.0
# 10                                8,993,497,000,000.0
# 11                                9,061,132,000,000.0
#
# 0  entity00164742_udf_IS_201711216052534_BasicEarningsLossPerShare  \
# 1                                          보통주 기본주당이익
# 2              Basic earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_201711216150750_BasicEarningsLossPerShare  \
# 1                                         1우선주 기본주당이익
# 2       Basic earnings (loss) per 1st preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_20171121623772_DilutedEarningsLossPerShare  \
# 1                                          보통주 희석주당이익
# 2            Diluted earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_20171121628395_DilutedEarningsLossPerShare
# 1                                         1우선주 희석주당이익
# 2         Diluted earnings (loss) per preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN

# %%
is_df.T.reset_index()
# Out:
#                                                     0  \
# 0   [D310000] Income statement, by function of exp...
# 1                                          concept_id
# 2                                   ifrs-full_Revenue
# 3                               ifrs-full_CostOfSales
# 4                               ifrs-full_GrossProfit
# 5      dart_TotalSellingGeneralAdministrativeExpenses
# 6                            dart_OperatingIncomeLoss
# 7                                     dart_OtherGains
# 8                                    dart_OtherLosses
# 9   entity00126380_udf_IS_2017102191515184_IncomeS...
# 10                            ifrs-full_FinanceIncome
# 11  entity00126380_udf_IS_2017102191643789_IncomeS...
# 12                      ifrs-full_ProfitLossBeforeTax
# 13     ifrs-full_IncomeTaxExpenseContinuingOperations
# 14       ifrs-full_ProfitLossFromContinuingOperations
# 15                               ifrs-full_ProfitLoss
# 16   ifrs-full_ProfitLossAttributableToOwnersOfParent
# 17  ifrs-full_ProfitLossAttributableToNoncontrolli...
# 18                ifrs-full_BasicEarningsLossPerShare
# 19              ifrs-full_DilutedEarningsLossPerShare
#
#                                                     1  \
# 0   [D310000] Income statement, by function of exp...
# 1                                            label_ko
# 2                                             수익(매출액)
# 3                                                매출원가
# 4                                               매출총이익
# 5                                             판매비와관리비
# 6                                                영업이익
# 7                                                기타수익
# 8                                                기타비용
# 9                                               지분법이익
# 10                                               금융수익
# 11                                               금융비용
# 12                                    법인세비용차감전순이익(손실)
# 13                                              법인세비용
# 14                                         계속영업이익(손실)
# 15                                          당기순이익(손실)
# 16                         지배기업의 소유주에게 귀속되는 당기순이익(손실)
# 17                              비지배지분에 귀속되는 당기순이익(손실)
# 18                                         기본주당이익(손실)
# 19                                         희석주당이익(손실)
#
#                                                     2                     3  \
# 0   [D310000] Income statement, by function of exp...     20210101-20211231
# 1                                            label_en             (연결재무제표,)
# 2                                      Revenue(Sales) 279,604,799,000,000.0
# 3                                       Cost of sales 166,411,342,000,000.0
# 4                                        Gross profit 113,193,457,000,000.0
# 5                 Selling and administrative expenses  61,559,601,000,000.0
# 6                                    Operating profit  51,633,856,000,000.0
# 7                          Other non-operating income   2,205,695,000,000.0
# 8                         Other non-operating expense   2,055,971,000,000.0
# 9   Share of net profit of associates and joint ve...     729,614,000,000.0
# 10                                   Financial income   8,543,187,000,000.0
# 11                                  Financial expense   7,704,554,000,000.0
# 12                           Profit before income tax  53,351,827,000,000.0
# 13                                 Income tax expense  13,444,377,000,000.0
# 14           Profit (loss) from continuing operations  39,907,450,000,000.0
# 15                       Profit (loss) for the period  39,907,450,000,000.0
# 16                       Owners of the parent company  39,243,791,000,000.0
# 17                          Non-controlling interests     663,659,000,000.0
# 18                    Basic earnings (loss) per share               5,777.0
# 19                  Diluted earnings (loss) per share               5,777.0
#
#                        4                     5                     6  \
# 0      20200101-20201231     20190101-20191231     20180101-20181231
# 1              (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 2  236,806,988,000,000.0 230,400,881,000,000.0 243,771,415,000,000.0
# 3  144,488,296,000,000.0 147,239,549,000,000.0 132,394,411,000,000.0
# 4   92,318,692,000,000.0  83,161,332,000,000.0 111,377,004,000,000.0
# 5   56,324,816,000,000.0  55,392,823,000,000.0  52,490,335,000,000.0
# 6   35,993,876,000,000.0  27,768,509,000,000.0  58,886,669,000,000.0
# 7    1,384,068,000,000.0   1,778,666,000,000.0   1,485,037,000,000.0
# 8    2,488,902,000,000.0   1,414,707,000,000.0   1,142,018,000,000.0
# 9      506,530,000,000.0     412,960,000,000.0     539,845,000,000.0
# 10  12,267,600,000,000.0  10,161,632,000,000.0   9,999,321,000,000.0
# 11  11,318,055,000,000.0   8,274,871,000,000.0   8,608,896,000,000.0
# 12  36,345,117,000,000.0  30,432,189,000,000.0  61,159,958,000,000.0
# 13   9,937,285,000,000.0   8,693,324,000,000.0  16,815,101,000,000.0
# 14  26,407,832,000,000.0  21,738,865,000,000.0  44,344,857,000,000.0
# 15  26,407,832,000,000.0  21,738,865,000,000.0  44,344,857,000,000.0
# 16  26,090,846,000,000.0  21,505,054,000,000.0  43,890,877,000,000.0
# 17     316,986,000,000.0     233,811,000,000.0     453,980,000,000.0
# 18               3,841.0               3,166.0               6,461.0
# 19               3,841.0               3,166.0               6,461.0
#
#                        7                     8
# 0      20170101-20171231     20160101-20161231
# 1              (연결재무제표,)             (연결재무제표,)
# 2  239,575,376,000,000.0 201,866,745,000,000.0
# 3  129,290,661,000,000.0 120,277,715,000,000.0
# 4  110,284,715,000,000.0  81,589,030,000,000.0
# 5   56,639,677,000,000.0  52,348,358,000,000.0
# 6   53,645,038,000,000.0  29,240,672,000,000.0
# 7    3,010,657,000,000.0   3,238,261,000,000.0
# 8    1,419,648,000,000.0   2,463,814,000,000.0
# 9      201,442,000,000.0      19,501,000,000.0
# 10   9,737,391,000,000.0  11,385,645,000,000.0
# 11   8,978,913,000,000.0  10,706,613,000,000.0
# 12  56,195,967,000,000.0  30,713,652,000,000.0
# 13  14,009,220,000,000.0   7,987,560,000,000.0
# 14  42,186,747,000,000.0  22,726,092,000,000.0
# 15  42,186,747,000,000.0  22,726,092,000,000.0
# 16  41,344,569,000,000.0  22,415,655,000,000.0
# 17     842,178,000,000.0     310,437,000,000.0
# 18               5,997.0               3,159.0
# 19               5,997.0               3,159.0

# %%
hy_is_df
# Out:
# 0  [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
# 1   [D310000] Income statement, by function of exp...
# 2   [D310000] Income statement, by function of exp...
# 3                                   20210101-20211231
# 4                                   20200101-20201231
# 5                                   20190101-20191231
# 6                                   20180101-20181231
# 7                                   20170101-20171231
# 8                                   20160101-20161231
# 9                                   20140101-20141231
# 10                                  20130101-20131231
# 11                                  20120101-20121231
#
# 0  concept_id     ifrs-full_Revenue ifrs-full_CostOfSales  \
# 1    label_ko                   매출액                  매출원가
# 2    label_en                 Sales         Cost of sales
# 3   (연결재무제표,) 117,610,626,000,000.0  95,680,131,000,000.0
# 4   (연결재무제표,) 103,997,601,000,000.0  85,515,931,000,000.0
# 5   (연결재무제표,) 105,746,422,000,000.0  88,091,409,000,000.0
# 6   (연결재무제표,)  96,812,609,000,000.0  81,670,479,000,000.0
# 7   (연결재무제표,)  96,376,079,000,000.0  78,798,172,000,000.0
# 8   (연결재무제표,)  93,649,024,000,000.0  75,959,720,000,000.0
# 9   (연결재무제표,)  89,256,319,000,000.0  70,126,276,000,000.0
# 10  (연결재무제표,)  87,307,636,000,000.0  67,859,491,000,000.0
# 11  (연결재무제표,)  84,469,721,000,000.0  64,967,273,000,000.0
#
# 0  ifrs-full_GrossProfit dart_TotalSellingGeneralAdministrativeExpenses  \
# 1                  매출총이익                                        판매비와관리비
# 2           Gross profit            Selling and administrative expenses
# 3   21,930,495,000,000.0                           15,251,546,000,000.0
# 4   18,481,670,000,000.0                           16,086,999,000,000.0
# 5   17,655,013,000,000.0                           14,049,508,000,000.0
# 6   15,142,130,000,000.0                           12,719,965,000,000.0
# 7   17,577,907,000,000.0                           13,003,240,000,000.0
# 8   17,689,304,000,000.0                           12,495,804,000,000.0
# 9   19,130,043,000,000.0                           11,580,057,000,000.0
# 10  19,448,145,000,000.0                           11,132,648,000,000.0
# 11  19,502,448,000,000.0                           11,061,847,000,000.0
#
# 0  dart_OperatingIncomeLoss  \
# 1                      영업이익
# 2    Operating income(loss)
# 3       6,678,949,000,000.0
# 4       2,394,671,000,000.0
# 5       3,605,505,000,000.0
# 6       2,422,165,000,000.0
# 7       4,574,667,000,000.0
# 8       5,193,500,000,000.0
# 9       7,549,986,000,000.0
# 10      8,315,497,000,000.0
# 11      8,440,601,000,000.0
#
# 0  entity00164742_udf_IS_201711292448594_IncomeStatementAbstract  \
# 1                                       공동기업및관계기업투자손익
# 2   Share of profit (loss) of associates and joint...
# 3                                 1,303,365,000,000.0
# 4                                   162,162,000,000.0
# 5                                   542,826,000,000.0
# 6                                   404,541,000,000.0
# 7                                   225,053,000,000.0
# 8                                 1,729,447,000,000.0
# 9                                 2,388,658,000,000.0
# 10                                3,057,109,000,000.0
# 11                                2,581,564,000,000.0
#
# 0  ifrs-full_FinanceIncome ifrs-full_FinanceCosts  ...  \
# 1                     금융수익                   금융비용  ...
# 2           Finance income          Finance costs  ...
# 3        912,802,000,000.0      548,410,000,000.0  ...
# 4        813,916,000,000.0      955,991,000,000.0  ...
# 5        827,120,000,000.0      475,218,000,000.0  ...
# 6        823,499,000,000.0      600,867,000,000.0  ...
# 7        972,943,000,000.0    1,120,386,000,000.0  ...
# 8      1,111,238,000,000.0      678,037,000,000.0  ...
# 9        881,883,000,000.0      601,019,000,000.0  ...
# 10       805,261,000,000.0      552,709,000,000.0  ...
# 11       969,726,000,000.0      624,473,000,000.0  ...
#
# 0  ifrs-full_IncomeTaxExpenseContinuingOperations  \
# 1                                           법인세비용
# 2                    Income tax expense (benefit)
# 3                             2,266,485,000,000.0
# 4                               168,703,000,000.0
# 5                               978,120,000,000.0
# 6                               884,563,000,000.0
# 7                              -107,850,000,000.0
# 8                             1,587,419,000,000.0
# 9                             2,301,806,000,000.0
# 10                            2,703,209,000,000.0
# 11                            2,549,310,000,000.0
#
# 0  entity00164742_udf_IS_201811515595499_IncomeStatementAbstract  \
# 1                                             연결당기순이익
# 2                                          Net income
# 3                                 5,693,077,000,000.0
# 4                                 1,924,553,000,000.0
# 5                                 3,185,646,000,000.0
# 6                                 1,645,019,000,000.0
# 7                                 4,546,400,000,000.0
# 8                                 5,719,653,000,000.0
# 9                                 7,649,468,000,000.0
# 10                                8,993,497,000,000.0
# 11                                9,061,132,000,000.0
#
# 0  ifrs-full_ProfitLossAttributableToOwnersOfParent  \
# 1                                         지배기업소유주지분
# 2   Profit (loss), attributable to owners of parent
# 3                               4,942,356,000,000.0
# 4                               1,424,436,000,000.0
# 5                               2,980,049,000,000.0
# 6                               1,508,084,000,000.0
# 7                               4,032,824,000,000.0
# 8                               5,406,435,000,000.0
# 9                               7,346,807,000,000.0
# 10                              8,541,834,000,000.0
# 11                              8,566,568,000,000.0
#
# 0  ifrs-full_ProfitLossAttributableToNoncontrollingInterests  \
# 1                                               비지배지분
# 2   Profit (loss), attributable to non-controlling...
# 3                                   750,721,000,000.0
# 4                                   500,117,000,000.0
# 5                                   205,597,000,000.0
# 6                                   136,935,000,000.0
# 7                                   513,576,000,000.0
# 8                                   313,218,000,000.0
# 9                                   302,661,000,000.0
# 10                                  451,663,000,000.0
# 11                                  494,564,000,000.0
#
# 0  ifrs-full_BasicEarningsLossPerShare  \
# 1                               기본주당이익
# 2      Basic earnings (loss) per share
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                             27,037.0
# 10                            31,441.0
# 11                            31,532.0
#
# 0  entity00164742_udf_IS_201711216052534_BasicEarningsLossPerShare  \
# 1                                          보통주 기본주당이익
# 2              Basic earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_201711216150750_BasicEarningsLossPerShare  \
# 1                                         1우선주 기본주당이익
# 2       Basic earnings (loss) per 1st preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  ifrs-full_DilutedEarningsLossPerShare  \
# 1                                 희석주당이익
# 2      Diluted earnings (loss) per share
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                               27,037.0
# 10                              31,441.0
# 11                              31,532.0
#
# 0  entity00164742_udf_IS_20171121623772_DilutedEarningsLossPerShare  \
# 1                                          보통주 희석주당이익
# 2            Diluted earnings (loss) per common stock
# 3                                            18,979.0
# 4                                             5,454.0
# 5                                            11,310.0
# 6                                             5,632.0
# 7                                            14,993.0
# 8                                            20,118.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# 0  entity00164742_udf_IS_20171121628395_DilutedEarningsLossPerShare
# 1                                         1우선주 희석주당이익
# 2         Diluted earnings (loss) per preferred stock
# 3                                            19,002.0
# 4                                             5,502.0
# 5                                            11,355.0
# 6                                             5,681.0
# 7                                            15,043.0
# 8                                            20,156.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# [11 rows x 23 columns]

# %% [markdown]
# # Solution
# xbrl을 이용해보자

# %%
dart.api.finance.xbrl_taxonomy(sj_div='BS1')
# Out:
# {'status': '000',
#  'message': '정상',
#  'list': [{'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_StatementOfFinancialPositionAbstract',
#    'account_nm': 'StatementOfFinancialPositionAbstract',
#    'label_kor': '재무상태표 [abstract]',
#    'label_eng': 'Statement of financial position [abstract]',
#    'ifrs_ref': ' '},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_AssetsAbstract',
#    'account_nm': 'AssetsAbstract',
#    'label_kor': '자산 [abstract]',
#    'label_eng': 'Assets [abstract]',
#    'ifrs_ref': ' '},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentAssets',
#    'account_nm': 'CurrentAssets',
#    'label_kor': '유동자산',
#    'label_eng': 'Current assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 60'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CashAndCashEquivalents',
#    'account_nm': 'CashAndCashEquivalents',
#    'label_kor': '현금및현금성자산',
#    'label_eng': 'Cash and cash equivalents',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_Cash',
#    'account_nm': 'Cash',
#    'label_kor': '현금',
#    'label_eng': 'Cash',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CashEquivalents',
#    'account_nm': 'CashEquivalents',
#    'label_kor': '현금성자산',
#    'label_eng': 'Cash equivalents',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GovernmentGrantsCashAndCashEquivalentsGross',
#    'account_nm': 'GovernmentGrantsCashAndCashEquivalentsGross',
#    'label_kor': '정부보조금',
#    'label_eng': 'Government grants, cash and cash equivalents',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1020 문단 24'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': 'ShortTermDepositsNotClassifiedAsCashEquivalents',
#    'label_kor': '단기금융상품',
#    'label_eng': 'Short-term deposits not classified as cash equivalents',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_TradeAndOtherCurrentReceivables',
#    'account_nm': 'TradeAndOtherCurrentReceivables',
#    'label_kor': '매출채권 및 기타유동채권',
#    'label_eng': 'Trade and other current receivables',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermTradeReceivable',
#    'account_nm': 'ShortTermTradeReceivable',
#    'label_kor': '매출채권',
#    'label_eng': 'Short-term trade Receivable',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermTradeReceivable',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermTradeReceivable',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term trade Receivable',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentFinanceLeaseReceivables',
#    'account_nm': 'CurrentFinanceLeaseReceivables',
#    'label_kor': '단기금융리스채권',
#    'label_eng': 'Current finance lease receivables',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountCurrentFinanceLeaseReceivables',
#    'account_nm': 'AllowanceForDoubtfulAcccountCurrentFinanceLeaseReceivables',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, current finance lease receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermDeferredAncillaryIncomeForLoans',
#    'account_nm': 'ShortTermDeferredAncillaryIncomeForLoans',
#    'label_kor': '단기이연대출부대수익',
#    'label_eng': 'Short-term deferred ancillary income for loans',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermDeferredAncillaryIncomeForLoans',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermDeferredAncillaryIncomeForLoans',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term deferred ancillary income for loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermOtherReceivables',
#    'account_nm': 'ShortTermOtherReceivables',
#    'label_kor': '단기미수금',
#    'label_eng': 'Short-term other Receivables',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermOtherReceivables',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermOtherReceivables',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term other Receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReceivablesOnConstructionContracts',
#    'account_nm': 'ReceivablesOnConstructionContracts',
#    'label_kor': '공사미수금',
#    'label_eng': 'Receivables On construction contracts',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountReceivablesOnConstructionContracts',
#    'account_nm': 'AllowanceForDoubtfulAcccountReceivablesOnConstructionContracts',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, receivables on construction contracts',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReceivablesRealestateSales',
#    'account_nm': 'ReceivablesRealestateSales',
#    'label_kor': '분양미수금',
#    'label_eng': 'Receivables realestate sales',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountReceivablesRealestateSales',
#    'account_nm': 'AllowanceForDoubtfulAcccountReceivablesRealestateSales',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, receivables realestate sales',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReceivablesAgent',
#    'account_nm': 'ReceivablesAgent',
#    'label_kor': '대행미수금',
#    'label_eng': 'Receivables agent',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountReceivablesAgent',
#    'account_nm': 'AllowanceForDoubtfulAcccountReceivablesAgent',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, receivables agent',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermAccruedIncome',
#    'account_nm': 'ShortTermAccruedIncome',
#    'label_kor': '단기미수수익',
#    'label_eng': 'Short-term accrued Income',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermAccruedIncome',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermAccruedIncome',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term accrued Income',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermDepositsProvided',
#    'account_nm': 'ShortTermDepositsProvided',
#    'label_kor': '단기보증금자산',
#    'label_eng': 'Short-term deposits Provided',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermDepositsProvided',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermDepositsProvided',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term deposits Provided',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermAdvancePayments',
#    'account_nm': 'ShortTermAdvancePayments',
#    'label_kor': '단기선급금',
#    'label_eng': 'Short-term advance payments',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermAdvancePayments',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermAdvancePayments',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term advance payments',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentValueAddedTaxReceivables',
#    'account_nm': 'CurrentValueAddedTaxReceivables',
#    'label_kor': '부가가치세대급금',
#    'label_eng': 'Current value added tax receivables',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermPrepaidExpenses',
#    'account_nm': 'ShortTermPrepaidExpenses',
#    'label_kor': '단기선급비용',
#    'label_eng': 'Short-term prepaid expenses',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermPrepaidExpenses',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermPrepaidExpenses',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount short-term prepaid expenses',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermPrepaidConstructionCosts',
#    'account_nm': 'ShortTermPrepaidConstructionCosts',
#    'label_kor': '단기선급공사원가',
#    'label_eng': 'Short-term prepaid construction costs',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermPrepaidConstructionCosts',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermPrepaidConstructionCosts',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term prepaid construction costs',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LeaseholdDeposits',
#    'account_nm': 'LeaseholdDeposits',
#    'label_kor': '단기임차보증금',
#    'label_eng': 'Leasehold deposits',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLeaseholdDeposits',
#    'account_nm': 'AllowanceForDoubtfulAcccountLeaseholdDeposits',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, leasehold deposits',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermContractReserve',
#    'account_nm': 'ShortTermContractReserve',
#    'label_kor': '단기공사유보금',
#    'label_eng': 'Short-term contract reserve',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentWorkoutReceivable',
#    'account_nm': 'CurrentWorkoutReceivable',
#    'label_kor': '유동회생채권',
#    'label_eng': 'Current workout receivable',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermDueFromCustomersForContractWork',
#    'account_nm': 'ShortTermDueFromCustomersForContractWork',
#    'label_kor': '단기미청구공사',
#    'label_eng': 'Short-term due from customers for contract work',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermDueFromCustomersForContractWork',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermDueFromCustomersForContractWork',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term due from customers for contract work',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentContractAssets',
#    'account_nm': 'CurrentContractAssets',
#    'label_kor': '유동계약자산',
#    'label_eng': 'Current contract assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1115 문단 105'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ShortTermLoans',
#    'account_nm': 'ShortTermLoans',
#    'label_kor': '단기대여금',
#    'label_eng': 'Short-term loans',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountShortTermLoans',
#    'account_nm': 'AllowanceForDoubtfulAcccountShortTermLoans',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, short-term loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentTaxAssets',
#    'account_nm': 'CurrentTaxAssets',
#    'label_kor': '당기법인세자산',
#    'label_eng': 'Current tax assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_Inventories',
#    'account_nm': 'Inventories',
#    'label_kor': '재고자산',
#    'label_eng': 'Inventories',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_RawMaterialsGross',
#    'account_nm': 'RawMaterialsGross',
#    'label_kor': '원재료',
#    'label_eng': 'Raw materials',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossRawMaterialsGross',
#    'account_nm': 'AccumulatedImpairmentLossRawMaterialsGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, raw materials',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ExperimentMaterialGross',
#    'account_nm': 'ExperimentMaterialGross',
#    'label_kor': '시험재료',
#    'label_eng': 'Experiment material, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossExperimentMaterialGross',
#    'account_nm': 'AccumulatedImpairmentLossExperimentMaterialGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated impairment loss, experiment material',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_MerchandiseGross',
#    'account_nm': 'MerchandiseGross',
#    'label_kor': '상품',
#    'label_eng': 'Merchandise, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossMerchandiseGross',
#    'account_nm': 'AccumulatedImpairmentLossMerchandiseGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, merchandise',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ProductionSuppliesGross',
#    'account_nm': 'ProductionSuppliesGross',
#    'label_kor': '소모품',
#    'label_eng': 'Production supplies, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossProductionSuppliesGross',
#    'account_nm': 'AccumulatedImpairmentLossProductionSuppliesGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, production supplies',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_WorkInProgressGross',
#    'account_nm': 'WorkInProgressGross',
#    'label_kor': '재공품',
#    'label_eng': 'Work in progress, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossWorkInProgressGross',
#    'account_nm': 'AccumulatedImpairmentLossWorkInProgressGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, work in progress',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_FinishedGoodsGross',
#    'account_nm': 'FinishedGoodsGross',
#    'label_kor': '제품',
#    'label_eng': 'Finished goods, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossFinishedGoodsGross',
#    'account_nm': 'AccumulatedImpairmentLossFinishedGoodsGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, finished goods',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_SemiFinishedGoodsGross',
#    'account_nm': 'SemiFinishedGoodsGross',
#    'label_kor': '반제품',
#    'label_eng': 'Semi-finished goods, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossSemiFinishedGoodsGross',
#    'account_nm': 'AccumulatedImpairmentLossSemiFinishedGoodsGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated impairment loss, semi-finished goods',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_SuppliesGross',
#    'account_nm': 'SuppliesGross',
#    'label_kor': '저장품',
#    'label_eng': 'Supplies, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossSuppliesGross',
#    'account_nm': 'AccumulatedImpairmentLossSuppliesGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, supplies',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GoodsInTransitGross',
#    'account_nm': 'GoodsInTransitGross',
#    'label_kor': '미착품',
#    'label_eng': 'Goods in transit, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossGoodsInTransitGross',
#    'account_nm': 'AccumulatedImpairmentLossGoodsInTransitGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, goods in transit',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ByProductGross',
#    'account_nm': 'ByProductGross',
#    'label_kor': '부산물',
#    'label_eng': 'By-product, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossByProductGross',
#    'account_nm': 'AccumulatedImpairmentLossByProductGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated impairment loss, by-product',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_FinishedHousingGross',
#    'account_nm': 'FinishedHousingGross',
#    'label_kor': '완성주택',
#    'label_eng': 'Finished housing, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossFinishedHousingGross',
#    'account_nm': 'AccumulatedImpairmentLossFinishedHousingGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated impairment loss, finished housing',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LotGross',
#    'account_nm': 'LotGross',
#    'label_kor': '용지',
#    'label_eng': 'Lot, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossLotGross',
#    'account_nm': 'AccumulatedImpairmentLossLotGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated impairment loss, lot',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherInventoriesGross',
#    'account_nm': 'OtherInventoriesGross',
#    'label_kor': '기타재고',
#    'label_eng': 'Other inventories, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossOtherInventoriesGross',
#    'account_nm': 'AccumulatedImpairmentLossOtherInventoriesGross',
#    'label_kor': '평가충당금',
#    'label_eng': 'Accumulated Impairment loss, other inventories',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (7),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78 (3)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_OtherCurrentFinancialAssets',
#    'account_nm': 'OtherCurrentFinancialAssets',
#    'label_kor': '기타유동금융자산',
#    'label_eng': 'Other current financial assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentAvailableForSaleFinancialAssets',
#    'account_nm': 'CurrentAvailableForSaleFinancialAssets',
#    'label_kor': '유동매도가능금융자산',
#    'label_eng': 'Current available-for-sale financial assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': 'CurrentFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'label_kor': '유동 기타포괄손익-공정가치 측정 금융자산',
#    'label_eng': 'Current financial assets measured at fair value through other comprehensive income',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1107 문단 8 (8)(가)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': 'CurrentInvestmentsInEquityInstrumentsDesignatedAtFairValueThroughOtherComprehensiveIncome',
#    'label_kor': '유동 기타포괄손익-공정가치 측정 지정 지분상품 투자',
#    'label_eng': 'Current investments in equity instruments designated at fair value through other comprehensive income',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1107 문단 8 (8)(나)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentFinancialAssetsHeldToMaturity',
#    'account_nm': 'CurrentFinancialAssetsHeldToMaturity',
#    'label_kor': '유동만기보유금융자산',
#    'label_eng': 'Current financial assets held to maturity',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentFinancialAssetsAtAmortisedCost',
#    'account_nm': 'CurrentFinancialAssetsAtAmortisedCost',
#    'label_kor': '유동 상각후원가 측정 금융자산',
#    'label_eng': 'Current financial assets at amortised cost',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1107 문단 8 (6)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentFinancialAssetHeldForTrading',
#    'account_nm': 'CurrentFinancialAssetHeldForTrading',
#    'label_kor': '유동단기매매금융자산',
#    'label_eng': 'Current financial asset held for trading',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentFinancialAssetsAtFairValueThroughProfitOrLossMandatorilyMeasuredAtFairValue',
#    'account_nm': 'CurrentFinancialAssetsAtFairValueThroughProfitOrLossMandatorilyMeasuredAtFairValue',
#    'label_kor': '유동 당기손익-공정가치 의무 측정 금융자산',
#    'label_eng': 'Current financial assets at fair value through profit or loss, mandatorily measured at fair value',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1107 문단 8 (1)(나)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentFinancialAssetDesignationAsAtFairValueThroughProfitOrLoss',
#    'account_nm': 'CurrentFinancialAssetDesignationAsAtFairValueThroughProfitOrLoss',
#    'label_kor': '유동당기손익인식지정금융자산',
#    'label_eng': 'Current financial asset designation as at fair value through profit or loss',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_CurrentFinancialAssetsAtFairValueThroughProfitOrLossDesignatedUponInitialRecognition',
#    'account_nm': 'CurrentFinancialAssetsAtFairValueThroughProfitOrLossDesignatedUponInitialRecognition',
#    'label_kor': '유동 당기손익-공정가치 측정 지정 금융자산',
#    'label_eng': 'Current financial assets at fair value through profit or loss, designated upon initial recognition or subsequently',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1107 문단 8 (1)(가)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentDerivativeAsset',
#    'account_nm': 'CurrentDerivativeAsset',
#    'label_kor': '유동파생상품자산',
#    'label_eng': 'Current derivative asset',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentFirmCommitmentAsset',
#    'account_nm': 'CurrentFirmCommitmentAsset',
#    'label_kor': '유동확정계약자산',
#    'label_eng': 'Current firm commitment asset',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4),K-IFRS 1001 문단 68,K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentBiologicalAssetsGross',
#    'account_nm': 'CurrentBiologicalAssetsGross',
#    'label_kor': '유동생물자산',
#    'label_eng': 'Current biological assets, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (6),K-IFRS 1001 문단 78'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GovernmentGrantsCurrentBiologicalAssetsGross',
#    'account_nm': 'GovernmentGrantsCurrentBiologicalAssetsGross',
#    'label_kor': '정부보조금',
#    'label_eng': 'Government grants, current biological assets',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1020 문단 24'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedDepreciationCurrentBiologicalAssetsGross',
#    'account_nm': 'AccumulatedDepreciationCurrentBiologicalAssetsGross',
#    'label_kor': '감가상각누계액',
#    'label_eng': 'Accumulated depreciation, current biological assets',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (6),K-IFRS 1001 문단 78,K-IFRS 1041 문단 30'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossCurrentBiologicalAssetsGross',
#    'account_nm': 'AccumulatedImpairmentLossCurrentBiologicalAssetsGross',
#    'label_kor': '손상차손누계액',
#    'label_eng': 'Accumulated Impairment loss, current biological assets',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (6),K-IFRS 1001 문단 78,K-IFRS 1041 문단 30'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherCurrentAssets',
#    'account_nm': 'OtherCurrentAssets',
#    'label_kor': '기타유동자산',
#    'label_eng': 'Other current assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 57'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentEmissionRight',
#    'account_nm': 'CurrentEmissionRight',
#    'label_kor': '유동배출권',
#    'label_eng': 'Current emission right',
#    'data_tp': 'X',
#    'ifrs_ref': '일반기업회계기준 33.13'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GovernmentGrantsCurrentEmissionRight',
#    'account_nm': 'GovernmentGrantsCurrentEmissionRight',
#    'label_kor': '정부보조금',
#    'label_eng': 'Government grants, current emission right',
#    'data_tp': '(X)',
#    'ifrs_ref': '일반기업회계기준 17.5'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AccumulatedImpairmentLossCurrentEmissionRight',
#    'account_nm': 'AccumulatedImpairmentLossCurrentEmissionRight',
#    'label_kor': '손상차손누계액',
#    'label_eng': 'Accumulated impairment loss, current emission right',
#    'data_tp': '(X)',
#    'ifrs_ref': '일반기업회계기준 33.5'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CurrentNoncashAssetsPledgedAsCollateralForWhichTransfereeHasRightByContractOrCustomToSellOrRepledgeCollateral',
#    'account_nm': 'CurrentNoncashAssetsPledgedAsCollateralForWhichTransfereeHasRightByContractOrCustomToSellOrRepledgeCollateral',
#    'label_kor': '양수자가 계약이나 관행에 따라 담보물을 매도하거나 다시 담보로 제공할 권리를 가지고 있는 유동 비현금담보물',
#    'label_eng': 'Current non-cash assets pledged as collateral for which transferee has right by contract or custom to sell or repledge collateral',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1039 문단 37 (1)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSaleOrAsHeldForDistributionToOwners',
#    'account_nm': 'NoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSaleOrAsHeldForDistributionToOwners',
#    'label_kor': '매각예정 또는 소유주에 대한 분배예정으로 분류된 비유동자산이나 처분자산집단',
#    'label_eng': 'Non-current assets or disposal groups classified as held for sale or as held for distribution to owners',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (10),K-IFRS 1001 문단 66'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_NoncurrentAssets',
#    'account_nm': 'NoncurrentAssets',
#    'label_kor': '비유동자산',
#    'label_eng': 'Non-current assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 60'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': 'LongTermDepositsNotClassifiedAsCashEquivalents',
#    'label_kor': '장기금융상품',
#    'label_eng': 'Long-term deposits not classified as cash equivalents',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (4)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentReceivablesGross',
#    'account_nm': 'LongTermTradeAndOtherNonCurrentReceivablesGross',
#    'label_kor': '장기매출채권 및 기타비유동채권',
#    'label_eng': 'Long-term trade and other non-current receivables, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermTradeReceivablesGross',
#    'account_nm': 'LongTermTradeReceivablesGross',
#    'label_kor': '장기매출채권',
#    'label_eng': 'Long-term trade receivables, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermTradeReceivablesGross',
#    'account_nm': 'PresentValueDiscountsLongTermTradeReceivablesGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term trade Receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermTradeReceivablesGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermTradeReceivablesGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term trade Receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_NoncurrentFinanceLeaseReceivable',
#    'account_nm': 'NoncurrentFinanceLeaseReceivable',
#    'label_kor': '장기금융리스채권',
#    'label_eng': 'Non-current finance lease receivables',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsNoncurrentFinanceLeaseReceivable',
#    'account_nm': 'PresentValueDiscountsNoncurrentFinanceLeaseReceivable',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, non-current finance lease receivable',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountNoncurrentFinanceLeaseReceivable',
#    'account_nm': 'AllowanceForDoubtfulAcccountNoncurrentFinanceLeaseReceivable',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, non-current finance lease receivable',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermDeferredAncillaryIncomeForLoans',
#    'account_nm': 'LongTermDeferredAncillaryIncomeForLoans',
#    'label_kor': '장기이연대출부대손익',
#    'label_eng': 'Long-term deferred ancillary income for loans',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermDeferredAncillaryIncomeForLoans',
#    'account_nm': 'PresentValueDiscountsLongTermDeferredAncillaryIncomeForLoans',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term deferred ancillaryIncome for loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermDeferredAncillaryIncomeForLoans',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermDeferredAncillaryIncomeForLoans',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term deferred ancillary income for loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermOtherReceivablesGross',
#    'account_nm': 'LongTermOtherReceivablesGross',
#    'label_kor': '장기미수금',
#    'label_eng': 'Long-term other Receivables, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermOtherReceivablesGross',
#    'account_nm': 'PresentValueDiscountsLongTermOtherReceivablesGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term other Receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermOtherReceivablesGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermOtherReceivablesGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term other Receivables',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermReceivablesOnConstructionContracts',
#    'account_nm': 'LongTermReceivablesOnConstructionContracts',
#    'label_kor': '장기공사미수금',
#    'label_eng': 'Long-term receivables on construction contracts',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermReceivablesOnConstructionContracts',
#    'account_nm': 'PresentValueDiscountsLongTermReceivablesOnConstructionContracts',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term receivables on construction contracts',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermReceivablesOnConstructionContracts',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermReceivablesOnConstructionContracts',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term receivables on construction contracts',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermReceivablesRealestateSales',
#    'account_nm': 'LongTermReceivablesRealestateSales',
#    'label_kor': '장기분양미수금',
#    'label_eng': 'Long-term receivables realestate sales',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermReceivablesRealestateSales',
#    'account_nm': 'PresentValueDiscountsLongTermReceivablesRealestateSales',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term receivables realestate sales',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermReceivablesRealestateSales',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermReceivablesRealestateSales',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term receivables realestate sales',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermReceivablesAgent',
#    'account_nm': 'LongTermReceivablesAgent',
#    'label_kor': '장기대행미수금',
#    'label_eng': 'Long-term receivables agent',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermReceivablesAgent',
#    'account_nm': 'PresentValueDiscountsLongTermReceivablesAgent',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts long-term receivables agent',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermReceivablesAgent',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermReceivablesAgent',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term receivables agent',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermAccruedIncomeGross',
#    'account_nm': 'LongTermAccruedIncomeGross',
#    'label_kor': '장기미수수익',
#    'label_eng': 'Long-term accrued Income, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermAccruedIncomeGross',
#    'account_nm': 'PresentValueDiscountsLongTermAccruedIncomeGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term accrued income',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermAccruedIncomeGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermAccruedIncomeGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term accrued Income',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermDepositsProvidedGross',
#    'account_nm': 'LongTermDepositsProvidedGross',
#    'label_kor': '장기보증금자산',
#    'label_eng': 'Long-term deposits provided, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermDepositsProvidedGross',
#    'account_nm': 'PresentValueDiscountsLongTermDepositsProvidedGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term deposits provided',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermDepositsProvidedGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermDepositsProvidedGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term deposits Provided',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermAdvancePaymentsGross',
#    'account_nm': 'LongTermAdvancePaymentsGross',
#    'label_kor': '장기선급금',
#    'label_eng': 'Long-term advance payments, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermAdvancePaymentsGross',
#    'account_nm': 'PresentValueDiscountsLongTermAdvancePaymentsGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term advance payments',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermAdvancePaymentsGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermAdvancePaymentsGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term advance payments',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermPrepaidExpenses',
#    'account_nm': 'LongTermPrepaidExpenses',
#    'label_kor': '장기선급비용',
#    'label_eng': 'Long-term prepaid expenses',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermPrepaidExpensesGross',
#    'account_nm': 'PresentValueDiscountsLongTermPrepaidExpensesGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term prepaid expenses',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermPrepaidExpensesGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermPrepaidExpensesGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term prepaid expenses',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermLoansGross',
#    'account_nm': 'LongTermLoansGross',
#    'label_kor': '장기대여금',
#    'label_eng': 'Long-term loans, gross',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermLoansGross',
#    'account_nm': 'PresentValueDiscountsLongTermLoansGross',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermLoansGross',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermLoansGross',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term loans',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermLeaseholdDeposits',
#    'account_nm': 'LongTermLeaseholdDeposits',
#    'label_kor': '장기임차보증금',
#    'label_eng': 'Long-term leasehold deposits',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_PresentValueDiscountsLongTermLeaseholdDeposits',
#    'account_nm': 'PresentValueDiscountsLongTermLeaseholdDeposits',
#    'label_kor': '현재가치할인차금',
#    'label_eng': 'Present value discounts, long-term leasehold deposits',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AllowanceForDoubtfulAcccountLongTermLeaseholdDeposits',
#    'account_nm': 'AllowanceForDoubtfulAcccountLongTermLeaseholdDeposits',
#    'label_kor': '대손충당금',
#    'label_eng': 'Allowance for doubtful acccount, long-term leasehold deposits',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LongTermDueFromCustomersForContractWork',
#    'account_nm': 'LongTermDueFromCustomersForContractWork',
#    'label_kor': '장기미청구공사',
#    'label_eng': 'Long-term due from customers for contract work',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (8),K-IFRS 1001 문단 60 ,K-IFRS 1001 문단 78 (2)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
# ...
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_SharePremium',
#    'account_nm': 'SharePremium',
#    'label_kor': '주식발행초과금',
#    'label_eng': 'Share premium',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GainsCapitalReduction',
#    'account_nm': 'GainsCapitalReduction',
#    'label_kor': '감자차익',
#    'label_eng': 'Gains capital reduction',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GainsSaleTreasuryStock',
#    'account_nm': 'GainsSaleTreasuryStock',
#    'label_kor': '자기주식처분이익',
#    'label_eng': 'Gains sale treasury stock',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ConsiderationConversionRightsCapitalSurplus',
#    'account_nm': 'ConsiderationConversionRightsCapitalSurplus',
#    'label_kor': '전환권대가',
#    'label_eng': 'Consideration conversion rights, capital surplus',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ConsiderationStockWarrantsCapitalSurplus',
#    'account_nm': 'ConsiderationStockWarrantsCapitalSurplus',
#    'label_kor': '신주인수권대가',
#    'label_eng': 'Consideration stock warrants, capital surplus',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ConsiderationExchangeableRightsCapitalSurplus',
#    'account_nm': 'ConsiderationExchangeableRightsCapitalSurplus',
#    'label_kor': '교환권대가',
#    'label_eng': 'Consideration exchangeable rights, capital surplus',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherCapitalSurplus',
#    'account_nm': 'OtherCapitalSurplus',
#    'label_kor': '기타자본잉여금',
#    'label_eng': 'Other capital surplus',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ElementsOfOtherStockholdersEquity',
#    'account_nm': 'ElementsOfOtherStockholdersEquity',
#    'label_kor': '기타자본구성요소',
#    'label_eng': "Elements of other stockholder's equity",
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_CapitalStockSubscribe',
#    'account_nm': 'CapitalStockSubscribe',
#    'label_kor': '신주청약증거금',
#    'label_eng': 'Capital stock subscribe',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_DiscountStockIssuance',
#    'account_nm': 'DiscountStockIssuance',
#    'label_kor': '주식할인발행차금',
#    'label_eng': 'Discount stock issuance',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_TreasuryShares',
#    'account_nm': 'TreasuryShares',
#    'label_kor': '자기주식',
#    'label_eng': 'Treasury shares',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LossesCapitalReduction',
#    'account_nm': 'LossesCapitalReduction',
#    'label_kor': '감자차손',
#    'label_eng': 'Losses capital reduction',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LossesSaleTreasuryStock',
#    'account_nm': 'LossesSaleTreasuryStock',
#    'label_kor': '자기주식처분손실',
#    'label_eng': 'Losses sale treasury stock',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_StockOptions',
#    'account_nm': 'StockOptions',
#    'label_kor': '주식선택권',
#    'label_eng': 'Stock options',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_NonVestingStocks',
#    'account_nm': 'NonVestingStocks',
#    'label_kor': '미가득주식',
#    'label_eng': 'Non-vesting stocks',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_DebtEquitySwap',
#    'account_nm': 'DebtEquitySwap',
#    'label_kor': '출자전환채무',
#    'label_eng': 'Debt equity swap',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherCapitalAdjustments',
#    'account_nm': 'OtherCapitalAdjustments',
#    'label_kor': '기타자본조정',
#    'label_eng': 'Other capital adjustments',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherComprehensiveIncomeLossAccumulatedAmount',
#    'account_nm': 'OtherComprehensiveIncomeLossAccumulatedAmount',
#    'label_kor': '기타포괄손익누계액',
#    'label_eng': 'Other Comprehensive income/loss accumulated amount',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherComprehensiveIncomeGainsLossesOnRevaluation',
#    'account_nm': 'OtherComprehensiveIncomeGainsLossesOnRevaluation',
#    'label_kor': '재평가잉여금',
#    'label_eng': 'Other comprehensive income gains losses on revaluation',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_OtherComprehensiveIncomeGainsLossesOnRemeasurementsOfDefinedBenefitPlans',
#    'account_nm': 'OtherComprehensiveIncomeGainsLossesOnRemeasurementsOfDefinedBenefitPlans',
#    'label_kor': '확정급여제도의 재측정손익',
#    'label_eng': 'Other comprehensive income gains gosses on remeasurements of defined benefit plans',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GainsValuationAvailableForSaleFinancialAssets',
#    'account_nm': 'GainsValuationAvailableForSaleFinancialAssets',
#    'label_kor': '매도가능금융자산평가이익',
#    'label_eng': 'Gains valuation available for sale financial assets',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LossValuationAvailableForSaleFinancialAssets',
#    'account_nm': 'LossValuationAvailableForSaleFinancialAssets',
#    'label_kor': '매도가능금융자산평가손실',
#    'label_eng': 'Loss valuation available for sale financial assets',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfGainsOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': 'ReserveOfGainsOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'label_kor': '기타포괄손익-공정가치 측정 금융자산 평가이익 적립금',
#    'label_eng': 'Reserve of gains on financial assets measured at fair value through other comprehensive income',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': 'ReserveOfLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'label_kor': '기타포괄손익-공정가치 측정 금융자산 평가손실 적립금',
#    'label_eng': 'Reserve of losses on financial assets measured at fair value through other comprehensive income',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfGainsOnHedgingInstrumentsThatHedgeInvestmentsInEquityInstruments',
#    'account_nm': 'ReserveOfGainsOnHedgingInstrumentsThatHedgeInvestmentsInEquityInstruments',
#    'label_kor': '지분상품투자에 대한 위험회피수단 평가이익 적립금',
#    'label_eng': 'Reserve of gains on hedging instruments that hedge investments in equity instruments',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfLossesOnHedgingInstrumentsThatHedgeInvestmentsInEquityInstruments',
#    'account_nm': 'ReserveOfLossesOnHedgingInstrumentsThatHedgeInvestmentsInEquityInstruments',
#    'label_kor': '지분상품투자에 대한 위험회피수단 평가손실 적립금',
#    'label_eng': 'Reserve of losses on hedging instruments that hedge investments in equity instruments',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_ReserveOfChangeInValueOfTimeValueOfOptions',
#    'account_nm': 'ReserveOfChangeInValueOfTimeValueOfOptions',
#    'label_kor': '옵션의 시간가치 변동 적립금',
#    'label_eng': 'Reserve of change in value of time value of options',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1109 문단 6.5.15,K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_ReserveOfChangeInValueOfForwardElementsOfForwardContracts',
#    'account_nm': 'ReserveOfChangeInValueOfForwardElementsOfForwardContracts',
#    'label_kor': '선도계약의 선도요소 가치 변동 적립금',
#    'label_eng': 'Reserve of change in value of forward elements of forward contracts',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1109 문단 6.5.16,K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_ReserveOfChangeInValueOfForeignCurrencyBasisSpreads',
#    'account_nm': 'ReserveOfChangeInValueOfForeignCurrencyBasisSpreads',
#    'label_kor': '외화베이시스스프레드 변동 적립금',
#    'label_eng': 'Reserve of change in value of foreign currency basis spreads',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1109 문단 6.5.16,K-IFRS 1001 문단 78 (5)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfGainsFromInvestmentsInEquityInstruments',
#    'account_nm': 'ReserveOfGainsFromInvestmentsInEquityInstruments',
#    'label_kor': '지분상품투자 평가이익 적립금',
#    'label_eng': 'Reserve of gains from investments in equity instruments',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)Common practice'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ReserveOfLossesFromInvestmentsInEquityInstruments',
#    'account_nm': 'ReserveOfLossesFromInvestmentsInEquityInstruments',
#    'label_kor': '지분상품투자 평가손실 적립금',
#    'label_eng': 'Reserve of losses from investments in equity instruments',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)Common practice'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_ReserveOfChangeInFairValueOfFinancialLiabilityAttributableToChangeInCreditRiskOfLiability',
#    'account_nm': 'ReserveOfChangeInFairValueOfFinancialLiabilityAttributableToChangeInCreditRiskOfLiability',
#    'label_kor': '신용위험 변동에 의한 금융부채 공정가치 변동 적립금',
#    'label_eng': 'Reserve of change in fair value of financial liability attributable to change in credit risk of liability',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 78 (5)Common practice'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GainsCumulativeEffectForeignCurrencyTranslation',
#    'account_nm': 'GainsCumulativeEffectForeignCurrencyTranslation',
#    'label_kor': '해외사업환산이익',
#    'label_eng': 'Gains cumulative effect foreign currency translation',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LossesCumulativeEffectForeignCurrencyTranslation',
#    'account_nm': 'LossesCumulativeEffectForeignCurrencyTranslation',
#    'label_kor': '해외사업환산손실',
#    'label_eng': 'Losses cumulative effect foreign currency translation',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_GainsValuationDerivativesCashFlowHedge',
#    'account_nm': 'GainsValuationDerivativesCashFlowHedge',
#    'label_kor': '현금흐름위험회피파생상품평가이익',
#    'label_eng': 'Gains valuation derivatives cash flow hedge',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LossesValuationDerivativesCashFlowHedge',
#    'account_nm': 'LossesValuationDerivativesCashFlowHedge',
#    'label_kor': '현금흐름위험회피파생상품평가손실',
#    'label_eng': 'Losses valuation derivatives cash flow hedge',
#    'data_tp': '(X)',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_ComprehensiveIncomeGainsLossesEquityMethodSecurities',
#    'account_nm': 'ComprehensiveIncomeGainsLossesEquityMethodSecurities',
#    'label_kor': '지분법기타포괄손익변동',
#    'label_eng': 'Comprehensive income gains losses equity method securities',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_RetainedEarnings',
#    'account_nm': 'RetainedEarnings',
#    'label_kor': '이익잉여금(결손금)',
#    'label_eng': 'Retained earnings',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_LegalReserve',
#    'account_nm': 'LegalReserve',
#    'label_kor': '이익준비금',
#    'label_eng': 'Legal Reserve',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_AppropriatedRetainedEarningsOtherLegalReserves',
#    'account_nm': 'AppropriatedRetainedEarningsOtherLegalReserves',
#    'label_kor': '기타법정적립금',
#    'label_eng': 'Appropriated retained earnings other legal reserves',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_VoluntaryReserves',
#    'account_nm': 'VoluntaryReserves',
#    'label_kor': '임의적립금',
#    'label_eng': 'Voluntary Reserves',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'dart_RetainedEarningsBeforeAppropriationsAccumulatedDeficitBeforeDisposition',
#    'account_nm': 'RetainedEarningsBeforeAppropriationsAccumulatedDeficitBeforeDisposition',
#    'label_kor': '미처분이익잉여금(미처리결손금)',
#    'label_eng': 'Retained earnings before appropriations(accumulated deficit before disposition)',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K-IFRS 1001 문단 58'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_NoncontrollingInterests',
#    'account_nm': 'NoncontrollingInterests',
#    'label_kor': '비지배지분',
#    'label_eng': 'Non-controlling interests',
#    'data_tp': 'X',
#    'ifrs_ref': 'K-IFRS 1001 문단 54 (17)'},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_Equity',
#    'account_nm': 'Equity',
#    'label_kor': '자본총계',
#    'label_eng': 'Total equity',
#    'ifrs_ref': ' '},
#   {'sj_div': 'BS1',
#    'bsns_de': '20180701',
#    'account_id': 'ifrs_EquityAndLiabilities',
#    'account_nm': 'EquityAndLiabilities',
#    'label_kor': '자본과부채총계',
#    'label_eng': 'Total equity and liabilities',
#    'ifrs_ref': ' '}]}

# %% [markdown]
# ### To dos
# - 유지보수를 위한 tutorial 노트북을 만들자.
# - 깔끔하게 위의 과정들을 Class나 함수로 구현하는 노트북을 하나 더 만들자.
# - 테이블 정의서에 맞도록 bf

# %%
import dart_fss as dart


# 삼성전자 code
corp_code = '00126380'

# 모든 상장된 기업 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자
samsung = corp_list.find_by_corp_code(corp_code=corp_code)

# %%
xbrl
# Out:
# {'Document information [text block]': nan, 'Document title': 'Annual Report', 'Amendment': 'false', 'Document creation date': '2021-12-31', 'Restatement of comparative financial statements': 'false'}

# %%
# 사업보고서 검색
reports = samsung.search_filings(bgn_de='20190101', pblntf_detail_ty='a001')

# 첫번째 리포트 선택
report = reports[0]

# 리포트의 xbrl 데이터
xbrl = report.xbrl

# 연결재무제표 존재 여부 확인( True / False)
xbrl.exist_consolidated()

# 감사 정보 (영문) -> DataFrame 형태로 반환됨
audit = xbrl.get_audit_information(lang='en')

# 연결 현금흐름표 추출 (리스트 반환)
cf = xbrl.get_cash_flows()

# 연결 현금프름표
cf = cf[0]

# Pandas DataFrame으로 변환
df = cf.to_DataFrame()

# Pandas DataFrame으로 변환 / 분류 정보 제외
df_wo_class = cf.to_DataFrame(show_class=True)
df_wo_class
# Out:
# Output()
# Output()
#    [D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0    ifrs-full_CashFlowsFromUsedInOperatingActivities
# 1   entity00126380_udf_CF_201710211099539_CashFlow...
# 2   entity00126380_udf_CF_201710211092510_udf_CF_2...
# 3   entity00126380_udf_CF_2017102110929616_udf_CF_...
# 4   entity00126380_udf_CF_2017102110934928_udf_CF_...
# 5   ifrs-full_InterestReceivedClassifiedAsOperatin...
# 6   ifrs-full_InterestPaidClassifiedAsOperatingAct...
# 7   ifrs-full_DividendsReceivedClassifiedAsOperati...
# 8   ifrs-full_IncomeTaxesPaidRefundClassifiedAsOpe...
# 9    ifrs-full_CashFlowsFromUsedInInvestingActivities
# 10  entity00126380_udf_CF_2017102110167395_CashFlo...
# 11  entity00126380_udf_CF_201987152650384_CashFlow...
# 12  entity00126380_udf_CF_2019726153251267_CashFlo...
# 13  dart_ProceedsFromSalesOfLongTermFinancialInstr...
# 14        dart_PurchaseOfLongTermFinancialInstruments
# 15  entity00126380_udf_CF_202182133547112_CashFlow...
# 16  entity00126380_udf_CF_2022221103235427_CashFlo...
# 17  entity00126380_udf_CF_2018510204038291_CashFlo...
# 18  entity00126380_udf_CF_2018510204040276_CashFlo...
# 19  entity00126380_udf_CF_2018510204036276_CashFlo...
# 20  entity00126380_udf_CF_2018510204025664_CashFlo...
# 21  entity00126380_udf_CF_202182133252272_CashFlow...
# 22  entity00126380_udf_CF_20171021101629633_CashFl...
# 23  ifrs-full_ProceedsFromSalesOfPropertyPlantAndE...
# 24  ifrs-full_PurchaseOfPropertyPlantAndEquipmentC...
# 25  ifrs-full_ProceedsFromSalesOfIntangibleAssetsC...
# 26  ifrs-full_PurchaseOfIntangibleAssetsClassified...
# 27  entity00126380_udf_CF_20171021101626447_CashFl...
# 28  entity00126380_udf_CF_202182134217299_CashFlow...
# 29  entity00126380_udf_CF_20171021101625672_CashFl...
# 30   ifrs-full_CashFlowsFromUsedInFinancingActivities
# 31  entity00126380_udf_CF_20171021102249949_CashFl...
# 32  entity00126380_udf_CF_2021111023423146_CashFlo...
# 33                dart_RepaymentsOfLongTermBorrowings
# 34  ifrs-full_DividendsPaidClassifiedAsFinancingAc...
# 35  entity00126380_udf_CF_20171021102253395_CashFl...
# 36  entity00126380_udf_CF_20201022202135156_Statem...
# 37  ifrs-full_EffectOfExchangeRateChangesOnCashAnd...
# 38  ifrs-full_IncreaseDecreaseInCashAndCashEquival...
# 39   dart_CashAndCashEquivalentsAtBeginningOfPeriodCf
# 40         dart_CashAndCashEquivalentsAtEndOfPeriodCf
#
#                               \
#                     label_ko
# 0                  영업활동 현금흐름
# 1              영업에서 창출된 현금흐름
# 2                      당기순이익
# 3                         조정
# 4         영업활동으로 인한 자산부채의 변동
# 5                     이자의 수취
# 6                     이자의 지급
# 7                     배당금 수입
# 8                    법인세 납부액
# 9                  투자활동 현금흐름
# 10           단기금융상품의 순감소(증가)
# 11      단기상각후원가금융자산의 순감소(증가)
# 12  단기당기손익-공정가치금융자산의 순감소(증가)
# 13                장기금융상품의 처분
# 14                장기금융상품의 취득
# 15             상각후원가금융자산의 처분
# 16             상각후원가금융자산의 취득
# 17       기타포괄손익-공정가치금융자산의 처분
# 18       기타포괄손익-공정가치금융자산의 취득
# 19         당기손익-공정가치금융자산의 처분
# 20         당기손익-공정가치금융자산의 취득
# 21        관계기업 및 공동기업 투자의 처분
# 22        관계기업 및 공동기업 투자의 취득
# 23                  유형자산의 처분
# 24                  유형자산의 취득
# 25                  무형자산의 처분
# 26                  무형자산의 취득
# 27           사업결합으로 인한 현금유출액
# 28     매각예정자산의 처분으로 인한 현금유입액
# 29        기타투자활동으로 인한 현금유출입액
# 30                 재무활동 현금흐름
# 31            단기차입금의 순증가(감소)
# 32                 장기차입금의 차입
# 33            사채 및 장기차입금의 상환
# 34                   배당금의 지급
# 35                 비지배지분의 증감
# 36                    매각예정분류
# 37          외화환산으로 인한 현금의 변동
# 38             현금및현금성자산의 순증감
# 39              기초의 현금및현금성자산
# 40              기말의 현금및현금성자산
#
#                                                                          \
#                                              label_en            class0
# 0      Cash flows from (used in) operating activities  현금흐름표 [abstract]
# 1                      Cash generated from operations  현금흐름표 [abstract]
# 2                          Profit (loss) for the year  현금흐름표 [abstract]
# 3                                         Adjustments  현금흐름표 [abstract]
# 4   Changes in assets and liabilities arising from...  현금흐름표 [abstract]
# 5                                   Interest received  현금흐름표 [abstract]
# 6                                       Interest paid  현금흐름표 [abstract]
# 7                                  Dividends received  현금흐름표 [abstract]
# 8                                   Income taxes paid  현금흐름표 [abstract]
# 9                Cash flows from investing activities  현금흐름표 [abstract]
# 10  Net decrease (increase) in short-term financia...  현금흐름표 [abstract]
# 11  Net decrease (increase) in short-term financia...  현금흐름표 [abstract]
# 12  Net decrease (increase) in short-term financia...  현금흐름표 [abstract]
# 13  Proceeds from sales of long-term financial ins...  현금흐름표 [abstract]
# 14        Purchase of long-term financial instruments  현금흐름표 [abstract]
# 15     Disposal of financial assets at amortized cost  현금흐름표 [abstract]
# 16  Acquisition of financial assets at amortized cost  현금흐름표 [abstract]
# 17  Disposal of financial assets at fair value thr...  현금흐름표 [abstract]
# 18  Acquisition of financial assets at fair value ...  현금흐름표 [abstract]
# 19  Disposal of financial assets at fair value thr...  현금흐름표 [abstract]
# 20  Acquisition of financial assets at fair value ...  현금흐름표 [abstract]
# 21  Disposal of investment in associates and joint...  현금흐름표 [abstract]
# 22  Acquisition of investment in associates and jo...  현금흐름표 [abstract]
# 23          Disposal of property, plant and equipment  현금흐름표 [abstract]
# 24       Acquisition of property, plant and equipment  현금흐름표 [abstract]
# 25                      Disposal of intangible assets  현금흐름표 [abstract]
# 26                   Acquisition of intangible assets  현금흐름표 [abstract]
# 27            Cash outflow from business combinations  현금흐름표 [abstract]
# 28      Cash inflow from sale of assets-held-for-sale  현금흐름표 [abstract]
# 29  Cash inflow (outflow) from other investing act...  현금흐름표 [abstract]
# 30               Cash flows from financing activities  현금흐름표 [abstract]
# 31   Net increase (decrease) in short-term borrowings  현금흐름표 [abstract]
# 32                   Increase in long-term borrowings  현금흐름표 [abstract]
# 33   Repayment of debentures and long-term borrowings  현금흐름표 [abstract]
# 34                                     Dividends paid  현금흐름표 [abstract]
# 35  Net increase (decrease) in non-controlling int...  현금흐름표 [abstract]
# 36                        Classified as held-for-sale  현금흐름표 [abstract]
# 37  Effect of exchange rate changes on cash and ca...  현금흐름표 [abstract]
# 38  Net increase (decrease) in cash and cash equiv...  현금흐름표 [abstract]
# 39   Cash and cash equivalents at beginning of period  현금흐름표 [abstract]
# 40         Cash and cash equivalents at end of period  현금흐름표 [abstract]
#
#                                                                     \
#               class1                    class2              class3
# 0          영업활동 현금흐름                      None                None
# 1          영업활동 현금흐름             영업에서 창출된 현금흐름                None
# 2          영업활동 현금흐름             영업에서 창출된 현금흐름               당기순이익
# 3          영업활동 현금흐름             영업에서 창출된 현금흐름                  조정
# 4          영업활동 현금흐름             영업에서 창출된 현금흐름  영업활동으로 인한 자산부채의 변동
# 5          영업활동 현금흐름                    이자의 수취                None
# 6          영업활동 현금흐름                    이자의 지급                None
# 7          영업활동 현금흐름                    배당금 수입                None
# 8          영업활동 현금흐름                   법인세 납부액                None
# 9          투자활동 현금흐름                      None                None
# 10         투자활동 현금흐름           단기금융상품의 순감소(증가)                None
# 11         투자활동 현금흐름      단기상각후원가금융자산의 순감소(증가)                None
# 12         투자활동 현금흐름  단기당기손익-공정가치금융자산의 순감소(증가)                None
# 13         투자활동 현금흐름                장기금융상품의 처분                None
# 14         투자활동 현금흐름                장기금융상품의 취득                None
# 15         투자활동 현금흐름             상각후원가금융자산의 처분                None
# 16         투자활동 현금흐름             상각후원가금융자산의 취득                None
# 17         투자활동 현금흐름       기타포괄손익-공정가치금융자산의 처분                None
# 18         투자활동 현금흐름       기타포괄손익-공정가치금융자산의 취득                None
# 19         투자활동 현금흐름         당기손익-공정가치금융자산의 처분                None
# 20         투자활동 현금흐름         당기손익-공정가치금융자산의 취득                None
# 21         투자활동 현금흐름        관계기업 및 공동기업 투자의 처분                None
# 22         투자활동 현금흐름        관계기업 및 공동기업 투자의 취득                None
# 23         투자활동 현금흐름                  유형자산의 처분                None
# 24         투자활동 현금흐름                  유형자산의 취득                None
# 25         투자활동 현금흐름                  무형자산의 처분                None
# 26         투자활동 현금흐름                  무형자산의 취득                None
# 27         투자활동 현금흐름           사업결합으로 인한 현금유출액                None
# 28         투자활동 현금흐름     매각예정자산의 처분으로 인한 현금유입액                None
# 29         투자활동 현금흐름        기타투자활동으로 인한 현금유출입액                None
# 30         재무활동 현금흐름                      None                None
# 31         재무활동 현금흐름            단기차입금의 순증가(감소)                None
# 32         재무활동 현금흐름                 장기차입금의 차입                None
# 33         재무활동 현금흐름            사채 및 장기차입금의 상환                None
# 34         재무활동 현금흐름                   배당금의 지급                None
# 35         재무활동 현금흐름                 비지배지분의 증감                None
# 36            매각예정분류                      None                None
# 37  외화환산으로 인한 현금의 변동                      None                None
# 38     현금및현금성자산의 순증감                      None                None
# 39      기초의 현금및현금성자산                      None                None
# 40      기말의 현금및현금성자산                      None                None
#
#        20210101-20211231                           20200101-20201231  \
#                (연결재무제표,)             (별도재무제표,)             (연결재무제표,)
# 0   65,105,448,000,000.0  51,250,069,000,000.0  65,287,009,000,000.0
# 1   72,676,199,000,000.0                   NaN  68,148,810,000,000.0
# 2   39,907,450,000,000.0                   NaN  26,407,832,000,000.0
# 3   49,055,633,000,000.0                   NaN  41,618,554,000,000.0
# 4  -16,286,884,000,000.0                   NaN     122,424,000,000.0
# 5    1,406,706,000,000.0     282,918,000,000.0   2,220,209,000,000.0
# 6      434,441,000,000.0     125,036,000,000.0     555,321,000,000.0
# 7      299,033,000,000.0   6,560,011,000,000.0     243,666,000,000.0
# 8    8,842,049,000,000.0   5,825,185,000,000.0   4,770,355,000,000.0
# 9  -33,047,763,000,000.0 -24,435,207,000,000.0 -53,628,591,000,000.0
# 10  10,917,128,000,000.0                   NaN -20,369,616,000,000.0
# 11    -336,959,000,000.0                   NaN     184,104,000,000.0
# 12      30,694,000,000.0                   NaN   1,704,512,000,000.0
# 13  10,216,082,000,000.0                   0.0  12,184,301,000,000.0
# 14   6,981,810,000,000.0                   NaN   8,019,263,000,000.0
# 15                   0.0                   NaN   1,023,117,000,000.0
# 16                   0.0                   NaN                   0.0
# 17   2,919,888,000,000.0                   NaN      32,128,000,000.0
# 18  -1,121,201,000,000.0                   NaN    -245,497,000,000.0
# 19     350,212,000,000.0                   NaN      39,746,000,000.0
# 20    -208,262,000,000.0                   NaN     -84,184,000,000.0
# 21      19,169,000,000.0                   NaN                   0.0
# 22     -47,090,000,000.0                   NaN     -83,280,000,000.0
# 23     358,284,000,000.0     408,560,000,000.0     376,744,000,000.0
# 24  47,122,106,000,000.0  36,021,504,000,000.0  37,592,034,000,000.0
# 25       1,752,000,000.0       5,809,000,000.0       7,027,000,000.0
# 26   2,706,915,000,000.0   2,459,929,000,000.0   2,679,779,000,000.0
# 27      -5,926,000,000.0                   NaN     -49,420,000,000.0
# 28     661,168,000,000.0                   NaN                   0.0
# 29       8,129,000,000.0                   NaN     -57,197,000,000.0
# 30 -23,991,033,000,000.0 -23,885,054,000,000.0  -8,327,839,000,000.0
# 31  -2,616,943,000,000.0                   NaN   2,191,186,000,000.0
# 32      58,279,000,000.0                   NaN      14,495,000,000.0
# 33     894,749,000,000.0     117,963,000,000.0     864,947,000,000.0
# 34  20,510,350,000,000.0  20,478,233,000,000.0   9,676,760,000,000.0
# 35     -27,270,000,000.0                   NaN       8,187,000,000.0
# 36         139,000,000.0                   NaN        -139,000,000.0
# 37   1,582,046,000,000.0          19,000,000.0    -833,861,000,000.0
# 38   9,648,837,000,000.0   2,929,827,000,000.0   2,496,579,000,000.0
# 39  29,382,578,000,000.0     989,045,000,000.0  26,885,999,000,000.0
# 40  39,031,415,000,000.0   3,918,872,000,000.0  29,382,578,000,000.0
#
#                              20190101-20191231
#                (별도재무제표,)             (별도재무제표,)             (연결재무제표,)
# 0   37,509,025,000,000.0  22,796,257,000,000.0  45,382,915,000,000.0
# 1                    NaN                   NaN  56,635,791,000,000.0
# 2                    NaN                   NaN  21,738,865,000,000.0
# 3                    NaN                   NaN  37,442,682,000,000.0
# 4                    NaN                   NaN  -2,545,756,000,000.0
# 5      448,323,000,000.0     673,363,000,000.0   2,306,401,000,000.0
# 6      148,262,000,000.0     306,633,000,000.0     579,979,000,000.0
# 7      129,569,000,000.0   4,625,181,000,000.0     241,801,000,000.0
# 8    2,462,259,000,000.0  10,540,360,000,000.0  13,221,099,000,000.0
# 9  -31,175,575,000,000.0 -13,537,171,000,000.0 -39,948,171,000,000.0
# 10                   NaN                   NaN  -2,030,913,000,000.0
# 11                   NaN                   NaN    -818,089,000,000.0
# 12                   NaN                   NaN     374,982,000,000.0
# 13                   0.0   1,400,000,000,000.0   4,586,610,000,000.0
# 14                   NaN                   NaN  12,725,465,000,000.0
# 15                   NaN                   NaN     694,584,000,000.0
# 16                   NaN                   NaN    -825,027,000,000.0
# 17                   NaN                   NaN       1,575,000,000.0
# 18                   NaN                   NaN     -63,773,000,000.0
# 19                   NaN                   NaN      64,321,000,000.0
# 20                   NaN                   NaN    -135,826,000,000.0
# 21                   NaN                   NaN      12,149,000,000.0
# 22                   NaN                   NaN     -12,778,000,000.0
# 23     431,142,000,000.0     600,901,000,000.0     513,265,000,000.0
# 24  26,962,042,000,000.0  17,240,242,000,000.0  25,367,756,000,000.0
# 25       1,082,000,000.0       1,965,000,000.0       7,241,000,000.0
# 26   2,239,834,000,000.0   2,855,959,000,000.0   3,249,914,000,000.0
# 27                   NaN                   NaN  -1,019,405,000,000.0
# 28                   NaN                   NaN                   0.0
# 29                   NaN                   NaN      46,048,000,000.0
# 30  -7,426,376,000,000.0  -9,787,719,000,000.0  -9,484,510,000,000.0
# 31                   NaN                   NaN     865,792,000,000.0
# 32                   NaN                   NaN                   0.0
# 33     134,443,000,000.0     128,431,000,000.0     709,400,000,000.0
# 34   9,618,283,000,000.0   9,618,210,000,000.0   9,639,202,000,000.0
# 35                   NaN                   NaN      -1,700,000,000.0
# 36                   NaN                   NaN                   0.0
# 37          54,000,000.0       2,593,000,000.0     595,260,000,000.0
# 38  -1,092,872,000,000.0    -526,040,000,000.0  -3,454,506,000,000.0
# 39   2,081,917,000,000.0   2,607,957,000,000.0  30,340,505,000,000.0
# 40     989,045,000,000.0   2,081,917,000,000.0  26,885,999,000,000.0

# %%
entity00126380_udf_CF_201710211099539_CashFlow...
