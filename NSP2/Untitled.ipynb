# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
retrieve_paths = [] 
for i in os.listdir(r'G:\공유 드라이브\HBS_DRN\NSP2 data_20220524\구색맞추기용') : 
    path = 'G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\구색맞추기용\\'+str(i)
    retrieve_paths.append(path)

# %%
all_df = pd.DataFrame()
for file in tqdm(retrieve_paths) : 
    df = pd.read_excel(file)
    all_df=all_df.append(df)
    print(len(all_df))
# Out:
#   3%|██▍                                                                                | 1/34 [00:24<13:39, 24.82s/it]
# 128179
#   6%|████▉                                                                              | 2/34 [00:50<13:26, 25.21s/it]
# 234120
#   9%|███████▎                                                                           | 3/34 [00:54<08:05, 15.65s/it]
# 256136
#  12%|█████████▊                                                                         | 4/34 [00:58<05:29, 10.99s/it]
# 272819
#  15%|████████████▏                                                                      | 5/34 [01:34<09:36, 19.89s/it]
# 472818
#  18%|██████████████▋                                                                    | 6/34 [02:15<12:42, 27.23s/it]
# 672818
#  21%|█████████████████                                                                  | 7/34 [02:52<13:43, 30.50s/it]
# 872818
# ...

# %%
test_sample = pd.read_csv(r'G:\공유 드라이브\HBS_DRN\NSP2 data_20220524\테스트용\Sample Data Autoparts.csv')

# %%
all_df = all_df.append(test_sample)

# %%
all_df.head()
# Out:
#                                     name  \
# 0                     Moorman Lijmwerken
# 1            Greven Administratiekantoor
# 2                           De Impressie
# 3  Wegwijzer Christelijke Basisschool De
# 4       Westhoek Openbare Basisschool De
#
#                                 name_eng description_short description  \
# 0                     Moorman Lijmwerken               NaN         NaN
# 1            Greven Administratiekantoor               NaN         NaN
# 2                           De Impressie               NaN         NaN
# 3  Wegwijzer Christelijke Basisschool De               NaN         NaN
# 4       Westhoek Openbare Basisschool De               NaN         NaN
#
#   founded_date               product                          homepage  \
# 0          NaN              Aannemer  http://www.moormanlijmwerken.nl/
# 1          NaN  Administratiekantoor            http://admingreven.nl/
# ...

# %%
len(all_df)
# Out:
# 4367825

# %%
len(all_df) - len(new)
# Out:
# 1083437

# %%
new = all_df.drop_duplicates(['name'], keep = 'last')

# %%
len(test_sample)
# Out:
# 250

# %%
new.iloc[-235:]['name']
# Out:
# 0              CDTi Advanced Materials, Inc.
# 1                          Leatt Corporation
# 2                             Worksport Ltd.
# 3                           Lear Corporation
# 4                      Dorman Products, Inc.
#                        ...
# 245    Xingda International Holdings Limited
# 246         Prinx Chengshan Holdings Limited
# 247                Zheng Li Holdings Limited
# 248             Hybrid Kinetic Group Limited
# 249                      Minth Group Limited
# Name: name, Length: 235, dtype: object

# %%
new.iloc[0:500000].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료1.xlsx')
new.iloc[500000:1000000].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료2.xlsx')
new.iloc[1000000:1500000].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료3.xlsx')
new.iloc[1500000:2000000].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료4.xlsx')
new.iloc[2500000:3000000].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료5.xlsx')
#new.iloc[3000000:-235].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료_테스트샘플.xlsx')
# Out:
# C:\Users\user\anaconda3\envs\codingNJ\lib\site-packages\xlsxwriter\worksheet.py:1179: UserWarning: Ignoring URL 'http://www.213collision.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\user\anaconda3\envs\codingNJ\lib\site-packages\xlsxwriter\worksheet.py:1179: UserWarning: Ignoring URL 'http://payless4wheeldrive.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\user\anaconda3\envs\codingNJ\lib\site-packages\xlsxwriter\worksheet.py:1179: UserWarning: Ignoring URL 'http://ohryisroel.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# ...

# %%
new.iloc[3000000:-235].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료6.xlsx')
new.iloc[-235:].to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료_테스트샘플.xlsx')

# %%
for i in range(6000000)

# %%
new.to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7444/1143442786.py in <module>
# ----> 1 new.to_excel('G:\\공유 드라이브\\HBS_DRN\\NSP2 data_20220524\\Final_중복검사완료.xlsx')
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     801         num_rows, num_cols = self.df.shape
# ...
