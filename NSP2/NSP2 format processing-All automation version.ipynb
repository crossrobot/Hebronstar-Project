# %%
import pandas as pd
import os

# %%
대응표주소 = r'C:\Users\user\codes\NSP2\대응표.xlsx'

# %%
대응표 = pd.read_excel(대응표주소, index_col = 0 )

# %%
original_sources= ['G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_1_말레이시아/말레이시아.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_2_싱가포르/싱가포르.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_3_태국/태국_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_4_베트남/베트남_v0.1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_4_베트남/베트남_v0.1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_5_인도네시아/인도네시아 .xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/2_6_인도/인도.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/1_1_한국/한국_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/1_2_일본/일본_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/1_2_일본/일본_2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/1_2_일본/일본_3.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/1_3_홍콩/홍콩_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_3.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_4_V2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_5.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_6.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_7.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_1_미국/미국_4_V2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_2_캐나다/캐나다.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_3_콜롬비아/콜롬비아1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_3_콜롬비아/콜롬비아2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_3_콜롬비아/콜롬비아3.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/3_4_멕시코/멕시코.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_1_네덜란드/네덜란드.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_2_독일/독일.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_3_이탈리아/이탈리아_1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_3_이탈리아/이탈리아_2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_4_프랑스/프랑스1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_4_프랑스/프랑스2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국1.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국2.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국3.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_6_호주/호주.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_7_스위스/스위스.xlsx',
 'G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_8_스페인/스페인.xlsx']

# %%
save_address= ['말레이시아.xlsx',
 '싱가포르.xlsx',
 '태국_1.xlsx',
 '베트남_v0.1.xlsx',
 '베트남_v0.1.xlsx',
 '인도네시아 .xlsx',
 '인도.xlsx',
 '한국_1.xlsx',
 '일본_1.xlsx',
 '일본_2.xlsx',
 '일본_3.xlsx',
 '홍콩_1.xlsx',
 '미국_1.xlsx',
 '미국_2.xlsx',
 '미국_3.xlsx',
 '미국_4_V2.xlsx',
 '미국_5.xlsx',
 '미국_6.xlsx',
 '미국_7.xlsx',
 '캐나다.xlsx',
 '콜롬비아1.xlsx',
 '콜롬비아2.xlsx',
 '콜롬비아3.xlsx',
 '멕시코.xlsx',
 '네덜란드.xlsx',
 '독일.xlsx',
 '이탈리아_1.xlsx',
 '이탈리아_2.xlsx',
 '프랑스1.xlsx',
 '프랑스2.xlsx',
 '영국1.xlsx',
 '영국2.xlsx',
 '영국3.xlsx',
 '호주.xlsx',
 '스위스.xlsx',
 '스페인.xlsx']

# %%
nation_dictionary1 = {"KOR" : "대한민국", "JPN" : "일본","HKG" : "홍콩", "MYS" : "말레이시아", "SGP" : "싱가포르", "THA" : '태국', "VNM" : "베트남", "IDN" : "인도네시아" ,"IND" : "인도", "USA" : "미국", "CAN" : "캐나다",
             "COL" : "콜롬비아", "MEX" : "멕시코", "NLD" : "네덜란드", "DEU" : "독일", "ITA" : "이탈리아","FRA":"프랑스", "GBR" : "영국", "AUS" : "호주", "CHE" : "스위스", "ESP" : "스페인" }

# %%
nation_dictionary = {"KOR" : 1, "JPN" : 2,"HKG" : 3, "MYS" : 4, "SGP" : 5, "THA" : 6, "VNM" : 7, "IDN" :8 ,"IND" : 9, "USA" : 10, "CAN" : 11,
             "COL" : 12, "MEX" : 13, "NLD" : 14, "DEU" : 15, "ITA" : 16, "FRA" : 17, "GBR" : 18, "AUS" : 19, "CHE" : 20, "ESP" : 21 }

# %%
for iter_num,file in enumerate(original_sources[30:]) : 
    
    
    processed_df = pd.DataFrame(columns = [element for element in 대응표['기준']])
    original = pd.read_excel(file)
    
    # 대응표의 '대응컬럼'으로 먼저 채울수 있는 정보를 채워 넣는다. 
    for target_col in 대응표['기준'] : 
        try : 
            processed_df[target_col] = original[대응표.loc[target_col,'대응컬럼']]

        except KeyError : 
            pass
        
    # 영어이름이 없는 row에서 'name'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['name_eng'].isna(), 'name_eng'] = processed_df.loc[processed_df['name_eng'].isna(), 'name']
    
    # product이 없는 row에서 '대안_영문주요제품내용'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_영문주요제품내용']

    # product이이 없는 row에서 '대안_현지언어산업군명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_현지언어산업군명']

    # product이이 없는 row에서 '대안_영문산업군명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_영문산업군명']
    
    # ceo가 없는 row에서 '영문대표이사명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['ceo_name'].isna(), 'ceo_name'] = processed_df.loc[processed_df['ceo_name'].isna(), '대안_영문대표이사명']

    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address1'].isna(), 'address1'] = processed_df.loc[processed_df['address1'].isna(), '대안_영문기업주소']
    
    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address1'].isna(), 'address1'] = processed_df.loc[processed_df['address1'].isna(), '대안_영문기업주소']
    
    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address2'].isna(), 'address2'] = processed_df.loc[processed_df['address2'].isna(), '대안_영문기업상세주소']
    
    # 국가코드 바꾸기. 세자리의 영어 명칭으로 되어있는 나라 이름을 nation_dictionary1을 조회하여 바꾸는 코드. 
    # 해당 코드는 description에 사용된다. 
    processed_df['대안_nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary1[x])
    
    try : 
        # 비어있는 description_short 채우기
        processed_df.loc[processed_df['description_short'].isna(), 'description_short'] = processed_df.loc[processed_df['description_short'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description_short'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description_short'].isna(), 'product'] + "입니다."

        # 비어있는 description 채우기
        processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description'].isna(), 'product'] + "입니다. 현재 기업의 대표는 " + processed_df.loc[processed_df['description'].isna(), 'ceo_name'] + " 씨 이며" + processed_df.loc[processed_df['description'].isna(), 'tel'] + " 을 통해 연락하실 수 있습니다."

        # 위의 코드를 실행하면, tel이 없는 기업의 경우 description cell이 비워져서 나오게 된다. 이럴경우, descrioption_short를 copy&paste한다.
        processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'description_short']
        
    except : 
        print(f"description을 생성하지 못한 파일은 {save_address[iter_num]} 입니다.")

    # 국가코드 바꾸기 
    processed_df['nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary[x])
    
    # 필요없는 열들 제거
    processed_df = processed_df.drop(['대안_영문한줄소개내용','대안_영문기업소개내용',"대안_영문주요제품내용","대안_영문대표이사명","대안_영문산업군명","대안_현지언어산업군명","대안_영문기업주소","대안_영문기업상세주소", "대안_nation_id"],axis=1)
    #  industry_code 1로 채우기 
    processed_df['industry_id'] = 1
    # 생성날짜 채워 넣기. 
    processed_df['created_at'] = '2022-05-20 00:10:00'
    processed_df['updated_at'] = '2022-05-20 00:10:00'
    
    processed_df.to_excel(save_address[iter_num])
    
    print(f"{save_address[iter_num]}이 저장 되었습니다.")
# Out:
# description을 생성하지 못한 파일은 말레이시아.xlsx 입니다.
# 말레이시아.xlsx이 저장 되었습니다.
# 싱가포르.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 태국_1.xlsx 입니다.
# 태국_1.xlsx이 저장 되었습니다.
# 베트남_v0.1.xlsx이 저장 되었습니다.
# 베트남_v0.1.xlsx이 저장 되었습니다.
# 인도네시아 .xlsx이 저장 되었습니다.
# 인도.xlsx이 저장 되었습니다.
# 한국_1.xlsx이 저장 되었습니다.
# 일본_1.xlsx이 저장 되었습니다.
# 일본_2.xlsx이 저장 되었습니다.
# 일본_3.xlsx이 저장 되었습니다.
# 홍콩_1.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_1.xlsx 입니다.
# 미국_1.xlsx이 저장 되었습니다.
# 미국_2.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_3.xlsx 입니다.
# 미국_3.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_4_V2.xlsx 입니다.
# 미국_4_V2.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_5.xlsx 입니다.
# 미국_5.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_6.xlsx 입니다.
# 미국_6.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 미국_7.xlsx 입니다.
# 미국_7.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 캐나다.xlsx 입니다.
# 캐나다.xlsx이 저장 되었습니다.
# 콜롬비아1.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 콜롬비아2.xlsx 입니다.
# 콜롬비아2.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 콜롬비아3.xlsx 입니다.
# 콜롬비아3.xlsx이 저장 되었습니다.
# 멕시코.xlsx이 저장 되었습니다.
# 네덜란드.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 독일.xlsx 입니다.
# 독일.xlsx이 저장 되었습니다.
# 이탈리아_1.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 이탈리아_2.xlsx 입니다.
# 이탈리아_2.xlsx이 저장 되었습니다.
# 프랑스1.xlsx이 저장 되었습니다.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20420/3595561754.py in <module>
#      39     # 국가코드 바꾸기. 세자리의 영어 명칭으로 되어있는 나라 이름을 nation_dictionary1을 조회하여 바꾸는 코드.
#      40     # 해당 코드는 description에 사용된다.
# ---> 41     processed_df['대안_nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary1[x])
#      42
#      43     try :
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_20420/3595561754.py in <lambda>(x)
#      39     # 국가코드 바꾸기. 세자리의 영어 명칭으로 되어있는 나라 이름을 nation_dictionary1을 조회하여 바꾸는 코드.
#      40     # 해당 코드는 description에 사용된다.
# ---> 41     processed_df['대안_nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary1[x])
#      42
#      43     try :
#
# KeyError: nan

# %%
for iter_num,file in enumerate(original_sources[30:]) : 
    print(file)
    print(save_address[iter_num+29])
# Out:
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_4_프랑스/프랑스2.xlsx
# 프랑스2.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국1.xlsx
# 영국1.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국2.xlsx
# 영국2.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_5_영국/영국3.xlsx
# 영국3.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_6_호주/호주.xlsx
# 호주.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_7_스위스/스위스.xlsx
# 스위스.xlsx
# G:/공유 드라이브/HBS_DRN/1_최종 클린징데이터/해외기업 일반정보/4_8_스페인/스페인.xlsx
# 스페인.xlsx

# %%
for iter_num,file in enumerate(original_sources[30:]) : 
    
    
    processed_df = pd.DataFrame(columns = [element for element in 대응표['기준']])
    original = pd.read_excel(file)
    
    # 대응표의 '대응컬럼'으로 먼저 채울수 있는 정보를 채워 넣는다. 
    for target_col in 대응표['기준'] : 
        try : 
            processed_df[target_col] = original[대응표.loc[target_col,'대응컬럼']]

        except KeyError : 
            pass
        
    # 영어이름이 없는 row에서 'name'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['name_eng'].isna(), 'name_eng'] = processed_df.loc[processed_df['name_eng'].isna(), 'name']
    
    # product이 없는 row에서 '대안_영문주요제품내용'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_영문주요제품내용']

    # product이이 없는 row에서 '대안_현지언어산업군명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_현지언어산업군명']

    # product이이 없는 row에서 '대안_영문산업군명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['product'].isna(), 'product'] = processed_df.loc[processed_df['product'].isna(), '대안_영문산업군명']
    
    # ceo가 없는 row에서 '영문대표이사명'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['ceo_name'].isna(), 'ceo_name'] = processed_df.loc[processed_df['ceo_name'].isna(), '대안_영문대표이사명']

    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address1'].isna(), 'address1'] = processed_df.loc[processed_df['address1'].isna(), '대안_영문기업주소']
    
    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address1'].isna(), 'address1'] = processed_df.loc[processed_df['address1'].isna(), '대안_영문기업주소']
    
    # 현지언어주요제품내용이 없는 row에서 '영문기업주소'을 조회하여 copy&paste. 
    processed_df.loc[processed_df['address2'].isna(), 'address2'] = processed_df.loc[processed_df['address2'].isna(), '대안_영문기업상세주소']
    
    # 국가코드 바꾸기. 세자리의 영어 명칭으로 되어있는 나라 이름을 nation_dictionary1을 조회하여 바꾸는 코드. 
    # 해당 코드는 description에 사용된다. 
    processed_df['대안_nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary1[x])
    
    try : 
        # 비어있는 description_short 채우기
        processed_df.loc[processed_df['description_short'].isna(), 'description_short'] = processed_df.loc[processed_df['description_short'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description_short'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description_short'].isna(), 'product'] + "입니다."

        # 비어있는 description 채우기
        processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description'].isna(), 'product'] + "입니다. 현재 기업의 대표는 " + processed_df.loc[processed_df['description'].isna(), 'ceo_name'] + " 씨 이며" + processed_df.loc[processed_df['description'].isna(), 'tel'] + " 을 통해 연락하실 수 있습니다."

        # 위의 코드를 실행하면, tel이 없는 기업의 경우 description cell이 비워져서 나오게 된다. 이럴경우, descrioption_short를 copy&paste한다.
        processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'description_short']
        
    except : 
        print(f"description을 생성하지 못한 파일은 {save_address[iter_num+29]} 입니다.")

    # 국가코드 바꾸기 
    processed_df['nation_id'] = processed_df['nation_id'].apply(lambda x : nation_dictionary[x])
    
    # 필요없는 열들 제거
    processed_df = processed_df.drop(['대안_영문한줄소개내용','대안_영문기업소개내용',"대안_영문주요제품내용","대안_영문대표이사명","대안_영문산업군명","대안_현지언어산업군명","대안_영문기업주소","대안_영문기업상세주소", "대안_nation_id"],axis=1)
    #  industry_code 1로 채우기 
    processed_df['industry_id'] = 1
    # 생성날짜 채워 넣기. 
    processed_df['created_at'] = '2022-05-20 00:10:00'
    processed_df['updated_at'] = '2022-05-20 00:10:00'
    
    processed_df.to_excel(save_address[iter_num+29])
    
    print(f"{save_address[iter_num+29]}이 저장 되었습니다.")
# Out:
# description을 생성하지 못한 파일은 프랑스2.xlsx 입니다.
# 프랑스2.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 영국1.xlsx 입니다.
# 영국1.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 영국2.xlsx 입니다.
# 영국2.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 영국3.xlsx 입니다.
# 영국3.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 호주.xlsx 입니다.
# 호주.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 스위스.xlsx 입니다.
# 스위스.xlsx이 저장 되었습니다.
# description을 생성하지 못한 파일은 스페인.xlsx 입니다.
# 스페인.xlsx이 저장 되었습니다.

# %%
processed_df.loc[processed_df['description_short'].isna(), 'description_short']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 131665   NaN
# 131666   NaN
# 131667   NaN
# 131668   NaN
# 131669   NaN
# Name: description_short, Length: 131670, dtype: float64

# %%
#|비어있는 description_short 채우기
processed_df.loc[processed_df['description_short'].isna(), 'description_short'] = processed_df.loc[processed_df['description_short'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description_short'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description_short'].isna(), 'product'] + "입니다."

# 비어있는 description 채우기
processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description'].isna(), 'product'] + "입니다. 현재 기업의 대표는 " + processed_df.loc[processed_df['description'].isna(), 'ceo_name'] + " 씨 이며" + processed_df.loc[processed_df['description'].isna(), 'tel'] + " 을 통해 연락하실 수 있습니다."

# 위의 코드를 실행하면, tel이 없는 기업의 경우 description cell이 비워져서 나오게 된다. 이럴경우, descrioption_short를 copy&paste한다.
processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'description_short']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20420/2534147144.py in <module>
#       1 #|비어있는 description_short 채우기
# ----> 2 processed_df.loc[processed_df['description_short'].isna(), 'description_short'] = processed_df.loc[processed_df['description_short'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description_short'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description_short'].isna(), 'product'] + "입니다."
#       3
#       4 # 비어있는 description 채우기
#       5 processed_df.loc[processed_df['description'].isna(), 'description'] = processed_df.loc[processed_df['description'].isna(), 'name'] +"은(는) "+ processed_df.loc[processed_df['description'].isna(), '대안_nation_id'] + "에 소재를 둔 기업입니다.  주요 판매 품목은 " +processed_df.loc[processed_df['description'].isna(), 'product'] + "입니다. 현재 기업의 대표는 " + processed_df.loc[processed_df['description'].isna(), 'ceo_name'] + " 씨 이며" + processed_df.loc[processed_df['description'].isna(), 'tel'] + " 을 통해 연락하실 수 있습니다."
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      87     @unpack_zerodim_and_defer("__add__")
#      88     def __add__(self, other):
# ---> 89         return self._arith_method(other, operator.add)
#      90
#      91     @unpack_zerodim_and_defer("__radd__")
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4996         lvalues = extract_array(self, extract_numpy=True)
#    4997         rvalues = extract_array(other, extract_numpy=True)
# -> 4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
#    5000         return self._construct_result(result, name=res_name)
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     147             #  will handle complex numbers incorrectly, see GH#32047
#     148             raise
# --> 149         result = _masked_arith_op(left, right, op)
#     150
#     151     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\envs\codingNJ\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     109         if mask.any():
#     110             with np.errstate(all="ignore"):
# --> 111                 result[mask] = op(xrav[mask], y)
#     112
#     113     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
processed_df
# Out:
#                              name                   name_eng  \
# 0                         Astoria                    Astoria
# 1                      NH Belagua                 NH Belagua
# 2       Catalonia Diagonal Centro  Catalonia Diagonal Centro
# 3                         Clipper                    Clipper
# 4        HERRERO RECUERO, CARLOS    HERRERO RECUERO, CARLOS
# ...                           ...                        ...
# 131665             Mis Bailarinas             Mis Bailarinas
# 131666              Pasito a Paso              Pasito a Paso
# 131667          Zapatería Pisotón          Zapatería Pisotón
# 131668        Calzados Milagritos        Calzados Milagritos
# 131669                      Tubet                      Tubet
#
#         description_short  description  founded_date      product homepage  \
# 0                     NaN          NaN           NaN        HOTEL      NaN
# 1                     NaN          NaN           NaN        HOTEL      NaN
# 2                     NaN          NaN           NaN        HOTEL      NaN
# 3                     NaN          NaN           NaN        HOTEL      NaN
# 4                     NaN          NaN           NaN  ARQUITECTOS      NaN
# ...                   ...          ...           ...          ...      ...
# 131665                NaN          NaN           NaN   ZAPATERIAS      NaN
# 131666                NaN          NaN           NaN   ZAPATERIAS      NaN
# 131667                NaN          NaN           NaN   ZAPATERIAS      NaN
# 131668                NaN          NaN           NaN   ZAPATERIAS      NaN
# 131669                NaN          NaN           NaN   ZAPATERIAS      NaN
#
#         employee_cnt  revenue  ceo_name  ... post_code facebook  youtube logo  \
# 0                NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 1                NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 2                NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 3                NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 4                NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# ...              ...      ...       ...  ...       ...      ...      ...  ...
# 131665           NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 131666           NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 131667           NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 131668           NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
# 131669           NaN      NaN       NaN  ...       NaN      NaN      NaN  NaN
#
#        hash_tag  nation_id  industry_id  is_active           created_at  \
# 0           NaN         21            1        NaN  2022-05-20 00:10:00
# 1           NaN         21            1        NaN  2022-05-20 00:10:00
# 2           NaN         21            1        NaN  2022-05-20 00:10:00
# 3           NaN         21            1        NaN  2022-05-20 00:10:00
# 4           NaN         21            1        NaN  2022-05-20 00:10:00
# ...         ...        ...          ...        ...                  ...
# 131665      NaN         21            1        NaN  2022-05-20 00:10:00
# 131666      NaN         21            1        NaN  2022-05-20 00:10:00
# 131667      NaN         21            1        NaN  2022-05-20 00:10:00
# 131668      NaN         21            1        NaN  2022-05-20 00:10:00
# 131669      NaN         21            1        NaN  2022-05-20 00:10:00
#
#                  updated_at
# 0       2022-05-20 00:10:00
# 1       2022-05-20 00:10:00
# 2       2022-05-20 00:10:00
# 3       2022-05-20 00:10:00
# 4       2022-05-20 00:10:00
# ...                     ...
# 131665  2022-05-20 00:10:00
# 131666  2022-05-20 00:10:00
# 131667  2022-05-20 00:10:00
# 131668  2022-05-20 00:10:00
# 131669  2022-05-20 00:10:00
#
# [131670 rows x 25 columns]
